# %% [markdown]
# #  URLs

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.giallozafferano.com/recipes-list/"
recipe_categories = ["Appetizers", "First-Courses", "Main-Courses", "Sweets-and-Desserts", "Leavened-products"]

recipes_urls = []
n_recipes_per_cat = {cat : 0 for cat in recipe_categories}

for category in recipe_categories:
    full_url = URL + category + "/"
    page = requests.get(full_url)

    soup = BeautifulSoup(page.content, "html.parser")
    results = soup.find_all("h2", class_ = "gz-title")
    for recipe in results:
        recipes_urls.append( recipe.find_all("a")[0]["href"] )
        n_recipes_per_cat[category] += 1
        
    additional_pages = [link["href"] for link in soup.find_all("a", class_ = "page")][1:]  
        
    for next_page in additional_pages:
        next_url = full_url + next_page[6:]
        page = requests.get(next_url)
        soup = BeautifulSoup(page.content, "html.parser")
        results = soup.find_all("h2", class_ = "gz-title")
        for recipe in results:
            recipes_urls.append( recipe.find_all("a")[0]["href"] )
            n_recipes_per_cat[category] += 1

# %%
print(len(recipes_urls))
print(n_recipes_per_cat)
# Out:
# 378
# {'Appetizers': 62, 'First-Courses': 111, 'Main-Courses': 73, 'Sweets-and-Desserts': 104, 'Leavened-products': 28}

# %%
recipes_urls[:2]
# Out:
# ['https://www.giallozafferano.com/recipes/Potato-tart.html',
#  'https://www.giallozafferano.com/recipes/Vegetable-pie.html']

# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq


pages = recipes_urls

list_of_names=[]
list_of_list_ing=[]
for j in range(len(pages)):
#  uClient = uReq(pages[j])
#  page_html=uClient.read()
#  uClient.close()
 page_html = requests.get(pages[j]).content
 page_soup = soup(page_html, "html.parser")


 rec_name = page_soup.find("h1")
 name = rec_name.get_text()
 list_of_names.append(name)
 ingredients = page_soup.findAll("dd")



 length=len(ingredients)
 
 ing_list=[]
 for element in ingredients:
   text_raw = element.get_text()
   name_raw = text_raw.split("\t")[0]
   name = name_raw.replace("\n","")
   name = name.replace("'","")
   ing_list.append(name)
 list_of_list_ing.append(ing_list)

# %%
list_of_names
# Out:
# ['Potato tart',
#  'Vegetable pie',
#  'Gourmet panettone',
#  'Scallops au gratin',
#  'Sciatt',
#  'Pumpkin bites',
#  'Panelle (chickpea flour fritters)',
#  'Zucchini with mint and vinegar',
#  'Puff pastry',
#  'Polenta medallions',
#  'Polenta chips',
#  'Savory Halloween pumpkin puffs',
#  'Baked eggplants',
#  'Spinach pie',
#  'tomino cheese in a puff pastry crust',
#  'Potato crumble',
#  'Rustic four-cheese pie',
#  'Zucchini fritters',
#  'salmon tartare with avocado and toasted almonds',
#  'Rustici leccesi (Puff pastry appetizers with béchamel, mozzarella, and tomato)',
#  'Breadsticks',
#  'Crostini with mussels and cherry tomatoes',
#  'Octopus salad with parsley',
#  'Stuffed zucchini swirls',
#  'Fried mozzarella and anchovy skewers',
#  'Savory eggplant pastry',
#  'Cheesy potato and zucchini balls',
#  'Angelica brioche with zucchini',
#  'Breaded zucchini and scamorza patties',
#  'Breaded eggplant parmigiana patties',
#  'Neapolitan pasta fritters',
#  'Pizza muffin',
#  'Pizza doughnuts',
#  'Mussels au gratin',
#  'Eggplant roulades',
#  'Quick and easy potato bombs',
#  'Mozzarella and tomato supplì',
#  'Rustic savory pie',
#  'Fruit salad',
#  'Mozzarella sticks',
#  'Vegetarian stuffed peppers',
#  'Arancini',
#  'Stuffed mozzarella roll',
#  'Chicken meatballs',
#  'Fried mussels',
#  'Fried chicken with quick mayo',
#  'Mini pasqualina tart parcels',
#  'Potato croquettes',
#  'Batter',
#  'Piadina Romagnola (Romagna-style flat bread)',
#  'Impepata di cozze (Steamed mussels with pepper)',
#  'Frittata (Egg-based dish)',
#  'Taralli (Round breadsticks)',
#  'Mozzarella in carrozza (Fried mozzarella)',
#  'Caponata (Eggplant salad)',
#  'Seafood salad',
#  'Gnocco fritto (Fried dough)',
#  'Insalata russa (Italian-style coleslaw)',
#  'Red miniature pizzas',
#  'Tomato bruschetta',
#  'Fried panzerotti (calzone)',
#  'Focaccia (fügassa) alla genovese (Genoa-style focaccia)',
#  'Cavatelli with speck, creamy potatoes and arugula',
#  'Pasta allo scarpariello',
#  'Chickpea and pumpkin soup',
#  'Spaghetti and meatballs',
#  'Orecchiette with broccoli and sausage',
#  'Fish soup',
#  'Porcini mushroom risotto',
#  'Neapolitan-style pasta and potatoes',
#  'Spatzle',
#  'Potato and ham pasta',
#  'Zucchini, tomato and sausage lasagna',
#  'Pumpkin gnocchi',
#  'Four-cheese pasta with speck',
#  'Orecchiette with broccoli rabe',
#  'Pumpkin and Gorgonzola risotto',
#  'Milanese-style pumpkin soup',
#  'Gorgonzola and walnut pasta',
#  'Sausage and Nebbiolo risotto',
#  'Vegetable soup',
#  'Creamy pumpkin, blue cheese and amaretto pasta',
#  'Pasta with smoked pancetta sauce',
#  'Pumpkin lasagna',
#  'Knödel',
#  'Pumpkin tortelli',
#  "Risotto all'amatriciana",
#  'Spinach pasta bake',
#  'Ricotta and spinach ravioli',
#  'Pumpkin risotto',
#  'Chickpea soup',
#  'Tagliatelle with porcini mushrooms',
#  'Gnocchi alla Romana',
#  'Acquacotta (Vegetable egg soup)',
#  'Saffron risotto',
#  'Four-cheese gnocchi',
#  'Ribollita (Tuscan soup)',
#  'Risotto al telefono',
#  'Lasagne with sausage ragu',
#  'Gnocchi alla sorrentina',
#  'Risotto alla pescatora',
#  'Eggplant pasta bake',
#  'Pasta with arugula & lemon pesto and cherry tomatoes',
#  'Seafood carbonara',
#  'Pasta and zucchini',
#  'Cheesy rice-stuffed eggplant',
#  'Pasta with ricotta cheese and basil',
#  'Pesto lasagna',
#  'Pasta alla Norma (Pasta with eggplant)',
#  'Rigatoni with sun-dried tomato pesto',
#  'Baked pasta nests',
#  'Vegetable couscous',
#  'Calamarata pasta with swordfish ragù',
#  'Paccheri pasta with calamari',
#  'Strozzapreti pasta with octopus sauce',
#  'Spaghetti aglio e olio (Spaghetti with garlic, oil and chili pepper)',
#  'Rice salad',
#  'Pasta with sardines',
#  'Sicilian-style mini penne',
#  'Casarecce pasta with musky octopus and eggplant',
#  'Spaghetti with mussels',
#  'Neapolitan pasta fritters',
#  'Pasta with stracchino cheese, bresaola, and cherry tomatoes',
#  'Pasta salad with ricotta and tomatoes',
#  'Pasta alla sorrentina',
#  'Spaghetti with creamy burrata and eggplant',
#  'Strozzapreti pasta with cacio cheese, mussels, and pepper',
#  'Cold pasta salad with salmon',
#  'Lasagna rolls',
#  'Baked trofie pasta',
#  'Tagliatelle with eggplant, pesto, and cherry tomatoes',
#  'Penne al baffo',
#  'Paccheri pasta with salmon',
#  'Calamarata (Pasta with calamari and tomato sauce)',
#  'Mediterranean pasta salad',
#  'Pasta alla vesuviana (Spicy pasta)',
#  'Rigatoni pie',
#  'Fusilli with zucchini pesto and salmon',
#  'Cannelloni with eggplant',
#  'Gnocchi with speck and walnuts',
#  'Pasta alla cenere (pasta with Gorgonzola and black olive sauce)',
#  'Paccheri pasta stuffed with sausage and mushrooms',
#  'Trofie pasta with creamy zucchini and pancetta',
#  'Fusilli pasta with pistachio pesto and cherry tomatoes',
#  'Baked pasta',
#  'Pasta with tuna',
#  'Potato gnocchi',
#  'Baked stuffed tomatoes',
#  'Spicy spaghetti nests',
#  'Lasagne alla Bolognese',
#  'Pizzoccheri alla valtellinese (Buckwheat flat pasta with cabbage)',
#  'Stuffed pasta shells',
#  'Ricotta and spinach ravioli with butter and sage',
#  'Crespelle (Crepes) cannelloni pasta',
#  'Spaghetti poveri (Spaghetti with anchovies, olives and capers)',
#  'Fettuccine pasta with octopus and porcini mushroom sauce',
#  'Pasta alla vecchia bettola (Old tavern pasta)',
#  'Pasta and lentils',
#  'Pasta alla zozzona (Carbonara, amatriciana and cacio e pepe pasta)',
#  'Passatelli (Homemade pasta nuggets) in broth',
#  'Homemade pasta (sheets and shapes)',
#  'Seafood spaghetti',
#  'Penne arrabbiata (Spicy penne pasta)',
#  'Spaghetti Puttanesca (Tomato, anchovy, olive and garlic spaghetti)',
#  'Spaghetti frittata',
#  'Spaghetti Amatriciana (Spaghetti with guanciale and tomato)',
#  'Spaghetti Carbonara (Spaghetti with guanciale and eggs)',
#  'Pasta alla gricia (Rigatoni with guanciale)',
#  'Paccheri pasta  with artichoke carbonara',
#  'Spaghetti Cacio e Pepe (Pecorino and black pepper spaghetti)',
#  'Spaghetti with tomato sauce',
#  'Spaghetti with clams',
#  'Cannelloni (Filled pasta tubes)',
#  'Potato tart',
#  'Vegetable pie',
#  'Spinach patties',
#  'Chicken meatloaf',
#  'Pumpkin bites',
#  'Polenta medallions',
#  'Beef stew with peas',
#  'Orange-roasted veal',
#  'Baked sausage and potatoes',
#  'Cod and potato casserole',
#  'Breaded cutlet rolls',
#  'Glazed BBQ ribs',
#  'tomino cheese in a puff pastry crust',
#  'Sausage and provolone pork loin rolls',
#  'Veal scalloppini with mushrooms',
#  'Pollo alla diavola (grilled chicken)',
#  'salmon tartare with avocado and toasted almonds',
#  'Potato frittata',
#  'Uova alla contadina (Baked eggs in tomato sauce)',
#  'Octopus salad with parsley',
#  'Fried mixed seafood',
#  'Meat and sausage-stuffed bell peppers',
#  'Chicken strips alla sorrentina',
#  'Savory eggplant pastry',
#  'Baked stuffed squid',
#  'Breaded zucchini and scamorza patties',
#  'Amalfi-style stuffed calamari',
#  'Sea bass in a herb salt crust',
#  'Chicken curry',
#  'Zucchini balls alla pizzaiola',
#  'Baked prawns',
#  'Prawn guazzetto',
#  'Stewed octopus',
#  'Beef fillet with green peppercorn sauce',
#  'Stuffed zucchini',
#  'Swordfish rolls',
#  'Omelette (basic recipe)',
#  'Veggie balls',
#  'Chicken breast with bell peppers',
#  'Chicken meatballs',
#  'Chicken drumstcks with mustard and bacon',
#  'Ham and cheese-filled veal rolls',
#  'Veal scalloppini with white wine and parsley',
#  'Beef tagliata',
#  'Chickpea burgers',
#  'Fried chicken with quick mayo',
#  'Roast veal with potatoes',
#  'Octopus and potato salad',
#  'Baked salmon steaks',
#  'Stuffed eggplants',
#  'Sicilian-style swordfish',
#  'Crunchy salmon',
#  'Sicilian-style chicken',
#  'Tasty chicken salad',
#  'Cotechino (Pork sausage) with lentils',
#  'Ricotta cheese fried balls with sauce',
#  'Cotechino (Pork sausage) in a pastry crust',
#  'Foil-baked sea bream',
#  'Potato gateau',
#  'Eggplant parmigiana',
#  'Chicken Cacciatore (Chicken stew with peppers)',
#  'Ossobuco Milanese (Braised veal shanks)',
#  'Brasato al Barolo (Beef stew with Barolo wine)',
#  'Frittata (Egg-based dish)',
#  'Meatloaf',
#  'Tasty chicken wings with potatoes',
#  'Saltimbocca alla Romana (Roman-style veal cutlets)',
#  'Ligurian-style stuffed zucchini',
#  'Seafood salad',
#  'Zucchini parmigiana',
#  'Veal stew with potatoes',
#  'Meatballs with tomato sauce',
#  'Veal Milanese (Breaded veal cutlet)',
#  "Panettone with brewer's yeast",
#  'Pandoro tree',
#  'Mascarpone cream',
#  'Pandoro cake',
#  'Star cookies',
#  'Candied almonds',
#  'Gingerbread cookies',
#  'Apple and orange cake',
#  'Ladyfinger Christmas house',
#  'Brioches',
#  'Chestnut and chocolate cake',
#  'Tuscan chestnut cake (Castagnaccio)',
#  'Gourmet tiramisu',
#  'Baked chestnuts',
#  'Pear and chocolate strudel',
#  'Yummy gluten-free chocolate cake',
#  'Puff pastry',
#  'Pear and chocolate cake',
#  'Chestnut and chocolate tart',
#  'Almond crumble (Sbrisolona)',
#  'Ricotta and chocolate chip pumpkin roll',
#  'Soft coffee and chocolate nougat',
#  'Sweet Halloween roll',
#  'Fig cake',
#  'Hot chocolate',
#  'Cinnamon rolls with liquid sourdough starter',
#  'Cappuccino and chocolate crumble',
#  'Apple tart',
#  'Butter and egg-free chocolate cake',
#  'Chocolate lava cake',
#  'Nutella crepes',
#  'Tiramisù truffles',
#  'Fruit tartlets',
#  'New York cheesecake',
#  'Lemon pastry cream pie',
#  'Fiordilatte ice cream',
#  'Pineapple upside-down cake',
#  'Rum babà (Rum syrup infused sponge cake)',
#  'Ricotta and chocolate cake',
#  'Wild berry strudel',
#  'Watermelon pizza',
#  'Blackberry pie',
#  'Coffee cream',
#  'Apple fritters',
#  'Banana cake',
#  'Nutella cheesecake',
#  'Coffee sorbet',
#  'Strawberry tiramisù',
#  'Leavened brioche braid',
#  'Milk cocoa sandwiches',
#  'Apple and ricotta fritters',
#  'Crème brûlée',
#  'Wild berry tiramisù',
#  'Cocoa sponge cake',
#  'Shortcrust pastry dough',
#  'Eggless tiramisù',
#  'Coffee puff pastry',
#  'Flourless chocolate cake',
#  'Apple and mascarpone cake',
#  'Chocolate profiteroles',
#  'Sponge cake',
#  'Zuppa inglese (Italian trifle)',
#  'Chiffon cake',
#  'Panna cotta',
#  'Lemon delights',
#  'Soft lemon cake',
#  'Danubio dolce (Sweet pull-apart brioche)',
#  'Crostata amalfitana (Lemon custard and sour cherry tart)',
#  'Chocolate cake',
#  'Nutella swirls',
#  'Creme Caramel',
#  'Strawberry cake',
#  'Quick Easter Colomba cake',
#  'Lingue di gatto (flat cookies)',
#  'Pastiera napoletana (Neapolitan ricotta cheese Easter pie)',
#  'Banana bread',
#  'Zeppole di San Giuseppe',
#  'Hot milk sponge cake',
#  'Butter and jam cookies',
#  'Sweet and savory crepes (Basic recipe)',
#  'Classic mimosa cake (Cake covered with sponge cake cubes)',
#  'No-bake yogurt cake',
#  'Chocolate custard cream',
#  'Graffe (Donuts)',
#  'Heart-shaped cake',
#  'Chiacchiere (Sweet fried dough)',
#  'Amor Polenta (Polenta sponge cake)',
#  'Nutellotti (Soft Nutella cookies)',
#  "Torta della nonna (Grandma's custard pie)",
#  'Magic vanilla cake',
#  'Torta tenerina (Moist  chocolate cake)',
#  'Almond crunch',
#  'Zuccotto di pandoro (Christmas sponge cake dessert)',
#  'Struffoli (Sweet fritters)',
#  'Ricotta Cheese Crostata (Tart)',
#  'Torta al limone (Lemon cake)',
#  'Chocolate salami',
#  'Torta caprese (Chocolate cake)',
#  'Zabaione (Egg cream)',
#  'Cannoli',
#  'Pastry cream',
#  'Apricot jam tart',
#  'Zeppole di Natale (Christmas fritters)',
#  'Tiramisù (Mascarpone cheese and ladyfingers dessert)',
#  "Panettone with brewer's yeast",
#  'Gourmet panettone',
#  'Brioches',
#  'Cinnamon rolls with liquid sourdough starter',
#  'Neapolitan pizza',
#  'Zucchini fritters',
#  'Breadsticks',
#  'Rum babà (Rum syrup infused sponge cake)',
#  'Angelica brioche with zucchini',
#  'Leavened brioche braid',
#  'Pizza doughnuts',
#  'Stuffed pizza roll',
#  'Liquid sourdough starter',
#  'Danubio dolce (Sweet pull-apart brioche)',
#  'Quick Easter Colomba cake',
#  'Danubio salato (Savory pull-apart bread)',
#  'Graffe (Donuts)',
#  'Sourdough starter',
#  'Pizza Margherita (Tomato and mozzarella pizza)',
#  'Bread dough',
#  'Gnocco fritto (Fried dough)',
#  'Milk bread',
#  'Fried pizza with mortadella and fior di latte cheese',
#  'Red miniature pizzas',
#  'Soft Focaccia',
#  'Fried panzerotti (calzone)',
#  'Focaccia (fügassa) alla genovese (Genoa-style focaccia)',
#  'Focaccia col formaggio (Recco-style cheese focaccia)']

# %%
list_of_list_ing
# Out:
# [['Potatoes',
#   'Cooked ham',
#   'Edam cheese',
#   'Gorgonzola cheese',
#   'Whipping cream',
#   'Eggs',
#   'Thyme',
#   'Fine salt',
#   'Black pepper'],
#  ['Puff pastry',
#   'Zucchini',
#   'Carrots',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Whole milk',
#   'Flour 00',
#   'Butter',
#   'Nutmeg',
#   'Parmigiano Reggiano DOP cheese',
#   'Eggs',
#   'Fine salt'],
#  ['Manitoba flour',
#   'Whole milk',
#   'Brewers yeast',
#   'Flour 0',
#   'Whole milk',
#   'Butter',
#   'Sugar',
#   'Eggs',
#   'Egg yolks',
#   'Brewers yeast',
#   'Fine salt',
#   'Malt',
#   'Cream cheese',
#   'Fresh liquid cream',
#   'Fine salt',
#   'Black pepper',
#   'Chives',
#   'Smoked Salmon',
#   'Asparagus',
#   'Robiola cheese',
#   'Fine salt',
#   'Black pepper',
#   'Goat',
#   'Tomato paste',
#   'Fresh liquid cream',
#   'Radicchio',
#   'Prosciutto cotto',
#   'Black pepper',
#   'Fine salt',
#   'Shrimps',
#   'Chives',
#   'Cocktail sauce'],
#  ['Scallops',
#   'Extra virgin olive oil',
#   'Marjoram',
#   'Bread',
#   'Lemon peel',
#   'Black pepper',
#   'Parsley',
#   'Fine salt',
#   'Thyme'],
#  ['Flour 00',
#   'Buckwheat flour',
#   'Blond beer',
#   'Sparkling water',
#   'Grappa',
#   'Fine salt',
#   'Black pepper',
#   'Valtellina Casera cheese',
#   'Peanut seed oil',
#   'Chickory',
#   'Extra virgin olive oil',
#   'Vinegar',
#   'Fine salt',
#   'Black pepper'],
#  ['Pumpkin',
#   'Breadcrumbs',
#   'Parmigiano Reggiano DOP cheese',
#   'Smoked scamorza cheese',
#   'Eggs',
#   'Sage',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Breadcrumbs',
#   'Vegetable oil'],
#  ['Chickpea flour',
#   'Water',
#   'Fine salt',
#   'Parsley',
#   'Sesame burger buns',
#   'Vegetable oil',
#   'Black pepper'],
#  ['Zucchini',
#   'Extra virgin olive oil',
#   'White wine vinegar',
#   'Garlic',
#   'Mint',
#   'Fine salt',
#   'Black pepper',
#   'Vegetable oil'],
#  ['Flour 00', 'Water', 'Fine salt', 'Butter', 'Flour 00'],
#  ['Instant flour for polenta',
#   'Water',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Smoked pancetta',
#   'Smoked scamorza cheese'],
#  ['Fioretto corn flour ',
#   'Water',
#   'Extra virgin olive oil',
#   'Rosemary',
#   'Coarse salt',
#   'Vegetable oil'],
#  ['Water',
#   'Butter',
#   'Flour 00',
#   'Fine salt',
#   'Eggs',
#   'Parmigiano Reggiano DOP cheese',
#   'Food coloring',
#   'Fresh cheese',
#   'Prosciutto cotto',
#   'Milk',
#   'Parmigiano Reggiano DOP cheese',
#   'Fine salt',
#   'Fresh cheese',
#   'Food coloring'],
#  ['Eggplant',
#   'Datterino tomatoes',
#   'Smoked scamorza cheese',
#   'Black olives',
#   'Capers',
#   'Extra virgin olive oil',
#   'Black pepper',
#   'Fine salt',
#   'Oregano'],
#  ['Butter',
#   'Black pepper',
#   'Flour 00',
#   'Water',
#   'Fine salt',
#   'Fine salt',
#   'Spinach',
#   'Fresh scallion',
#   'Extra virgin olive oil',
#   'Thyme',
#   'Eggs',
#   'Whipping cream',
#   'Caciocavallo cheese'],
#  ['Black pepper',
#   'Tomini cheese',
#   'Puff pastry',
#   'Cooked ham',
#   'Thyme',
#   'Egg yolks',
#   'Whipping cream'],
#  ['Red potatoes',
#   'Mozzarella di bufala cheese',
#   'Rolled Pancetta ',
#   'Eggs',
#   'Parmigiano Reggiano DOP cheese',
#   'Gluten free cornstarch',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Puff pastry',
#   'Gruyere cheese',
#   'Gorgonzola cheese',
#   'Scamorza (provola) cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Cooked ham',
#   'Thyme',
#   'Sage'],
#  ['Zucchini',
#   'Parmigiano Reggiano DOP cheese',
#   'Flour 00',
#   'Brewers yeast',
#   'Water',
#   'Fine salt',
#   'Peanut seed oil',
#   'Fine salt'],
#  ['Salmon fillets',
#   'Black pepper',
#   'Almond flakes',
#   'Fresh ginger',
#   'Tabasco®',
#   'Lime peel',
#   'Chives',
#   'Fine salt',
#   'Rice vinegar',
#   'Black pepper',
#   'Piccadilly tomatoes',
#   'Avocado',
#   'Lime juice',
#   'Fine salt'],
#  ['Puff pastry',
#   'Tomato puree',
#   'Mozzarella cheese',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Whole milk',
#   'Flour 00',
#   'Butter',
#   'Fine salt',
#   'Black pepper',
#   'Nutmeg',
#   'Eggs'],
#  ['Water',
#   'Fresh brewers yeast',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Barley malt',
#   'Semolina',
#   'Flour 00',
#   'Extra virgin olive oil'],
#  ['Mussels',
#   'Baguette',
#   'White wine',
#   'Garlic',
#   'Cherry tomatoes',
#   'Extra virgin olive oil',
#   'Parsley',
#   'Pepper',
#   'Fine salt'],
#  ['Octopus',
#   'Carrots',
#   'Celery',
#   'Garlic',
#   'Bay leaves',
#   'Ground black pepper',
#   'Fine salt',
#   'Parsley',
#   'Lemon juice',
#   'Extra virgin olive oil',
#   'Black pepper',
#   'Fine salt'],
#  ['Zucchini',
#   'Eggs',
#   'Edam cheese',
#   'Fine salt',
#   'Prosciutto cotto',
#   'Black pepper',
#   'Breadcrumbs',
#   'Peanut seed oil'],
#  ['Mozzarella cheese',
#   'Long loaf sandwich bread',
#   'Anchovies in oil',
#   'Whole milk',
#   'Eggs',
#   'Breadcrumbs',
#   'Peanut seed oil'],
#  ['Puff pastry',
#   'Eggplant',
#   'Scamorza (provola) cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Sun-dried tomatoes in oil',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Potatoes',
#   'Zucchini',
#   'Smoked provola cheese',
#   'Flour 00',
#   'Parmigiano Reggiano DOP cheese',
#   'Breadcrumbs',
#   'Eggs',
#   'Fine salt',
#   'Breadcrumbs',
#   'Peanut seed oil'],
#  ['Manitoba flour',
#   'Water',
#   'Fresh brewers yeast',
#   'Flour 00',
#   'Whole milk',
#   'Butter',
#   'Fine salt',
#   'Sugar',
#   'Zucchini',
#   'Caciocavallo cheese',
#   'Almond flakes',
#   'Shallot',
#   'Thyme',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Water',
#   'Extra virgin olive oil'],
#  ['Zucchini',
#   'Scamorza (provola) cheese',
#   'Breadcrumbs',
#   'Grana Padano DOP cheese',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil',
#   'Nutmeg',
#   'Eggs',
#   'Breadcrumbs'],
#  ['Tomato puree',
#   'Round eggplants',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Garlic',
#   'Parmigiano Reggiano DOP cheese',
#   'Basil',
#   'Fior di latte mozzarella cheese',
#   'Breadcrumbs',
#   'Eggs',
#   'Vegetable oil'],
#  ['Bucatini pasta',
#   'Cooked ham',
#   'Frozen peas',
#   'Garlic',
#   'Extra virgin olive oil',
#   'Peanut seed oil',
#   'Fine salt',
#   'Flour 00',
#   'Butter',
#   'Whole milk',
#   'Fine salt',
#   'Nutmeg',
#   'Water',
#   'Flour 00'],
#  ['Water',
#   'Flour 00',
#   'Fine salt',
#   'Baking powder',
#   'Mozzarella cheese',
#   'Tomato puree',
#   'Extra virgin olive oil',
#   'Oregano'],
#  ['Flour 00',
#   'Water',
#   'Baking powder',
#   'Fine salt',
#   'Mozzarella cheese',
#   'Canned tomatoes',
#   'Oregano',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Mussels',
#   'Breadcrumbs',
#   'Grana Padano DOP cheese',
#   'Garlic',
#   'Lemon peel',
#   'Parsley',
#   'Extra virgin olive oil',
#   'Black pepper'],
#  ['Eggplant',
#   'Cooked ham',
#   'Caciocavallo cheese',
#   'Tomato puree',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Potatoes',
#   'Flour 00',
#   'Baking powder',
#   'Eggs',
#   'Fine salt',
#   'Cooked ham',
#   'Smoked scamorza cheese',
#   'Oregano',
#   'Sunflower seed oil',
#   'Maldon salt'],
#  ['Carnaroli rice',
#   'Yellow onions',
#   'Tomato puree',
#   'Vegetable broth',
#   'Mozzarella cheese',
#   'Grana Padano DOP cheese',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Eggs',
#   'Breadcrumbs',
#   'Corn oil'],
#  ['Water',
#   'Flour 00',
#   'Butter',
#   'Fine salt',
#   'Speck',
#   'Potatoes',
#   'Fontina cheese',
#   'Thyme',
#   'Paprika',
#   'Fine salt',
#   'Black pepper',
#   'Whole milk'],
#  ['Nectarines',
#   'Cherries',
#   'Blueberries',
#   'Strawberries',
#   'Figs',
#   'Celery',
#   'Peanuts',
#   'Lemon juice',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Mozzarella cheese',
#   'Flour 00',
#   'Eggs',
#   'Breadcrumbs',
#   'Corn flakes',
#   'Fine salt',
#   'Peeled tomatoes',
#   'White onions',
#   'Whipping cream',
#   'Garlic',
#   'Fresh chili pepper',
#   'Fine salt',
#   'Brown sugar',
#   'Extra virgin olive oil',
#   'Peanut seed oil'],
#  ['Bell peppers',
#   'Potatoes',
#   'Zucchini',
#   'Cherry tomatoes',
#   'Scamorza (provola) cheese',
#   'Thyme',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Saffron',
#   'Butter',
#   'Vialone nano rice',
#   'Fine salt',
#   'Water',
#   'Caciocavallo cheese',
#   'Fine salt',
#   'Black pepper',
#   'Onions',
#   'Butter',
#   'Pork',
#   'Extra virgin olive oil',
#   'Tomato puree',
#   'Peas',
#   'Caciocavallo cheese',
#   'Red wine',
#   'Cooked ham',
#   'Mozzarella cheese',
#   'Flour 00',
#   'Fine salt',
#   'Water',
#   'Breadcrumbs',
#   'Vegetable oil'],
#  ['Mozzarella cheese',
#   'Prosciutto crudo',
#   'Cluster tomatoes',
#   'Arugula',
#   'Water',
#   'Fine salt'],
#  ['Chicken',
#   'Mozzarella cheese',
#   'Breadcrumbs',
#   'Parmigiano Reggiano DOP cheese',
#   'Eggs',
#   'Oregano',
#   'Fine salt',
#   'Black pepper',
#   'Eggs',
#   'Breadcrumbs',
#   'Vegetable oil'],
#  ['Mussels',
#   'White bread loaf',
#   'Eggs',
#   'Parmigiano Reggiano DOP cheese',
#   'Breadcrumbs',
#   'Parsley',
#   'Fine salt',
#   'Black pepper',
#   'Sunflower seed oil'],
#  ['Chicken breast',
#   'Rosemary',
#   'Lemon juice',
#   'Lemon peel',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Smoked paprika',
#   'Soy milk',
#   'Rice vinegar',
#   'Wasabi',
#   'Chives',
#   'Tabasco®',
#   'Fine salt',
#   'Dijon mustard',
#   'Acacia honey',
#   'Vegetable oil',
#   'Flour 00',
#   'Corn flakes',
#   'Eggs',
#   'Rosemary',
#   'Vegetable oil'],
#  ['Puff pastry',
#   'Chard',
#   'Eggs',
#   'Cows milk ricotta cheese',
#   'Pecorino cheese',
#   'Nutmeg',
#   'Fine salt',
#   'Black pepper',
#   'Egg yolks',
#   'Whipping cream'],
#  ['Red potatoes',
#   'Egg yolks',
#   'Nutmeg',
#   'Black pepper',
#   'Fine salt',
#   'Parmigiano Reggiano DOP cheese',
#   'Eggs',
#   'Breadcrumbs',
#   'Peanut seed oil'],
#  ['Eggs', 'Flour 00', 'Whole milk', 'Fine salt'],
#  ['Flour 00', 'Lard', 'Water', 'Fine salt', 'Baking soda'],
#  ['Mussels', 'Black pepper', 'Parsley', 'Lemons'],
#  ['Eggs',
#   'Pecorino cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Flour 00', 'Dry white wine', 'Extra virgin olive oil', 'Fine salt'],
#  ['White bread loaf',
#   'Mozzarella di bufala cheese',
#   'Fine salt',
#   'Eggs',
#   'Flour 00',
#   'Breadcrumbs',
#   'Sunflower seed oil'],
#  ['Eggplant',
#   'Celery',
#   'White onions',
#   'Cluster tomatoes',
#   'Green olives in brine',
#   'Salted capers',
#   'Pine nuts',
#   'Sugar',
#   'White wine vinegar',
#   'Basil',
#   'Tomato paste',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Extra virgin olive oil'],
#  ['Mussels',
#   'Clams',
#   'Shrimps',
#   'Octopus',
#   'Calamari (squid)',
#   'Carrots',
#   'Celery',
#   'Bay leaves',
#   'Parsley',
#   'Garlic',
#   'Pink peppercorn',
#   'Ground black pepper',
#   'Lemon juice',
#   'Extra virgin olive oil',
#   'Parsley',
#   'Fine salt',
#   'Black pepper'],
#  ['Lard',
#   'Flour 0',
#   'Sugar',
#   'Fine salt',
#   'Water',
#   'Whole milk',
#   'Baking powder',
#   'Vegetable oil'],
#  ['Carrots',
#   'Peas',
#   'Potatoes',
#   'Eggs',
#   'Extra virgin olive oil',
#   'Apple cider vinegar',
#   'Fine salt',
#   'Black pepper',
#   'Egg yolks',
#   'Sunflower seed oil',
#   'Lemon juice',
#   'Vinegar',
#   'Black pepper',
#   'Fine salt'],
#  ['Water',
#   'Flour 00',
#   'Fresh brewers yeast',
#   'Sugar',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Tomato puree',
#   'Mozzarella cheese',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil',
#   'Oregano'],
#  ['Homemade bread',
#   'Cluster tomatoes',
#   'Basil',
#   'Oregano',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Flour 00',
#   'Manitoba flour',
#   'Water',
#   'Extra virgin olive oil',
#   'Fresh brewers yeast',
#   'Sugar',
#   'Fine salt',
#   'Fior di latte mozzarella cheese',
#   'Tomato puree',
#   'Fine salt',
#   'Oregano',
#   'Extra virgin olive oil',
#   'Vegetable oil'],
#  ['Flour 00',
#   'Manitoba flour',
#   'Water',
#   'Fine salt',
#   'Malt',
#   'Fresh brewers yeast',
#   'Extra virgin olive oil',
#   'Extra virgin olive oil',
#   'Extra virgin olive oil',
#   'Salt',
#   'Water'],
#  ['Cavatelli pasta',
#   'Speck',
#   'Potatoes',
#   'Arugula',
#   'Whipping cream',
#   'Parmigiano Reggiano DOP cheese',
#   'Thyme',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Spaghetti',
#   'Datterino tomatoes',
#   'Pecorino Romano cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Basil',
#   'Fresh chili pepper',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Fine salt'],
#  ['Delica pumpkin',
#   'Precooked chickpeas',
#   'Chard',
#   'Yellow onions',
#   'Juniper berries',
#   'Bay leaves',
#   'Water',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Spaghetti',
#   'Tomato puree',
#   'Shallot',
#   'Garlic',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Pork',
#   'Luganega sausage',
#   'Mortadella',
#   'Wholegrain bread',
#   'Parmigiano Reggiano DOP cheese',
#   'Parsley',
#   'Eggs',
#   'Nutmeg',
#   'Black pepper',
#   'Fine salt'],
#  ['Orecchiette pasta',
#   'Broccoli',
#   'Sausage',
#   'White wine',
#   'Garlic',
#   'Thyme',
#   'Rosemary',
#   'Extra virgin olive oil',
#   'Black pepper',
#   'Fine salt'],
#  ['Shrimps',
#   'Cuttlefish',
#   'Gurnard',
#   'Monkfish',
#   'Goatfish',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Parsley',
#   'White wine',
#   'Fine salt',
#   'Black pepper',
#   'Tomato puree',
#   'Celery',
#   'Carrots',
#   'White onions',
#   'Water',
#   'Ground white pepper',
#   'Parsley',
#   'Mussels',
#   'Extra virgin olive oil',
#   'Garlic'],
#  ['Carnaroli rice',
#   'Porcini mushrooms',
#   'Vegetable broth',
#   'Yellow onions',
#   'Garlic',
#   'Butter',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Parmigiano Reggiano DOP cheese',
#   'Butter',
#   'Parsley'],
#  ['Mixed Pasta ',
#   'Potatoes',
#   'Celery',
#   'Carrots',
#   'White onions',
#   'Lard',
#   'Tomato paste',
#   'Rosemary',
#   'Parmigiano Reggiano DOP cheese',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Flour 00', 'Eggs', 'Water', 'Fine salt', 'Nutmeg', 'Chives', 'Butter'],
#  ['Extra virgin olive oil',
#   'White wine',
#   'Mezze Maniche Rigate pasta',
#   'Sage',
#   'Parsley',
#   'Potatoes',
#   'Prosciutto cotto',
#   'Black pepper',
#   'Meat broth',
#   'Shallot',
#   'Fine salt'],
#  ['Green Lasagne egg pasta',
#   'Zucchini',
#   'Sausage',
#   'Grana Padano DOP cheese',
#   'Shallot',
#   'Tomato paste',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Datterino tomatoes',
#   'Thyme',
#   'Oregano',
#   'Brown sugar',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Whole milk',
#   'Butter',
#   'Flour 00',
#   'Fine salt',
#   'Nutmeg'],
#  ['Mantuan pumpkin',
#   'Red potatoes',
#   'Flour 00',
#   'Potato starch',
#   'Eggs',
#   'Fine salt',
#   'Black pepper',
#   'Nutmeg'],
#  ['Speck',
#   'Fusilli pasta',
#   'Gorgonzola cheese',
#   'Taleggio cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Gruyere cheese',
#   'Whole milk',
#   'Whipping cream',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Broccoli rabe',
#   'Breadcrumbs',
#   'Fine salt',
#   'Garlic',
#   'Anchovies in oil',
#   'Extra virgin olive oil',
#   'Water',
#   'Remilled durum wheat semolina',
#   'Fine salt'],
#  ['Carnaroli rice',
#   'Delica pumpkin',
#   'Gorgonzola cheese',
#   'Yellow onions',
#   'Butter',
#   'White wine',
#   'Extra virgin olive oil',
#   'Rosemary',
#   'Fine salt',
#   'Black pepper',
#   'Water',
#   'Celery',
#   'Yellow onions',
#   'Carrots',
#   'Parsley',
#   'Fine salt'],
#  ['Ditaloni rigati pasta',
#   'Pumpkin',
#   'Water',
#   'Whole milk',
#   'Grana Padano DOP cheese',
#   'Fine salt',
#   'Black pepper'],
#  ['Trofie pasta',
#   'Gorgonzola cheese',
#   'Whipping cream',
#   'Walnut kernels',
#   'Thyme',
#   'Black pepper',
#   'Fine salt'],
#  ['Carnaroli rice',
#   'Extra virgin olive oil',
#   'Butter',
#   'Onions',
#   'Bra sausage',
#   'Meat broth',
#   'White wine',
#   'Onions',
#   'Extra virgin olive oil',
#   'Butter',
#   'Nebbiolo grape',
#   'Rosemary',
#   'Bay leaves',
#   'Butter',
#   'Parmigiano Reggiano DOP cheese'],
#  ['Water',
#   'Carrots',
#   'Fine salt',
#   'Borlotti beans',
#   'Cauliflower',
#   'Peas',
#   'Red onions',
#   'Black pepper',
#   'Pumpkin',
#   'Rosemary',
#   'White zucchini',
#   'Celery',
#   'Extra virgin olive oil',
#   'Bay leaves',
#   'Potatoes',
#   'Cluster tomatoes',
#   'Leeks',
#   'Extra virgin olive oil'],
#  ['Fusilli bucati corti pasta',
#   'Pumpkin',
#   'Rosemary',
#   'Extra virgin olive oil',
#   'Yellow onions',
#   'Fine salt',
#   'Black pepper',
#   'Cinnamon powder',
#   'Vegetable broth',
#   'Amaretti cookies',
#   'Gorgonzola cheese'],
#  ['Sedanini Rigati pasta',
#   'Smoked pancetta',
#   'Peeled tomatoes',
#   'Celery',
#   'Onions',
#   'White wine',
#   'Fresh chili pepper',
#   'Basil',
#   'Black pepper',
#   'Fine salt',
#   'Extra virgin olive oil'],
#  ['Green egg lasagna sheets',
#   'Pumpkin',
#   'Vegetable broth',
#   'Extra virgin olive oil',
#   'Rosemary',
#   'Fine salt',
#   'Black pepper',
#   'Parmigiano Reggiano DOP cheese',
#   'Garlic',
#   'Provola cheese',
#   'Whole milk',
#   'Butter',
#   'Flour 00',
#   'Nutmeg'],
#  ['Stale bread',
#   'Speck',
#   'White onions',
#   'Eggs',
#   'Whole milk',
#   'Butter',
#   'Black pepper',
#   'Parsley',
#   'Chives'],
#  ['Flour 00',
#   'Eggs',
#   'Mantuan pumpkin',
#   'Amaretti cookies',
#   'Mantuan mustard',
#   'Grana Padano DOP cheese',
#   'Eggs',
#   'Nutmeg',
#   'Fine salt'],
#  ['Carnaroli rice',
#   'Guanciale',
#   'Peeled tomatoes',
#   'Pecorino Romano cheese',
#   'Dry white wine',
#   'Vegetable broth',
#   'Fine salt',
#   'Black pepper'],
#  ['Rigatoni',
#   'Whipping cream',
#   'Black pepper',
#   'Spinach',
#   'Parmigiano Reggiano DOP cheese',
#   'Gorgonzola cheese',
#   'Thyme',
#   'Mascarpone cheese',
#   'Extra virgin olive oil'],
#  ['Flour 00',
#   'Eggs',
#   'Semolina',
#   'Spinach',
#   'Cows milk ricotta cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Nutmeg',
#   'Fine salt',
#   'Black pepper'],
#  ['Carnaroli rice',
#   'Pumpkin',
#   'Yellow onions',
#   'Vegetable broth',
#   'Parmigiano Reggiano DOP cheese',
#   'White wine',
#   'Butter',
#   'Black pepper',
#   'Fine salt',
#   'Extra virgin olive oil'],
#  ['Dried chickpeas',
#   'Carrots',
#   'Celery',
#   'White onions',
#   'Leeks',
#   'Extra virgin olive oil',
#   'Rosemary',
#   'Fine salt',
#   'Black pepper',
#   'Bay leaves',
#   'Vegetable broth',
#   'Tomato puree'],
#  ['Flour 00',
#   'Eggs',
#   'Semolina',
#   'Porcini mushrooms',
#   'Butter',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Garlic',
#   'Parsley',
#   'Black pepper'],
#  ['Semolina',
#   'Whole milk',
#   'Butter',
#   'Egg yolks',
#   'Parmigiano Reggiano DOP cheese',
#   'Pecorino cheese',
#   'Fine salt',
#   'Nutmeg'],
#  ['Yellow onions',
#   'Celery',
#   'Peeled tomatoes',
#   'Extra virgin olive oil',
#   'Water',
#   'Vegetable broth',
#   'Fine salt',
#   'Basil',
#   'Eggs',
#   'Tuscan bread',
#   'Pecorino cheese',
#   'Extra virgin olive oil',
#   'Basil'],
#  ['Saffron threads',
#   'Carnaroli rice',
#   'Butter',
#   'Onions',
#   'Grana Padano DOP cheese',
#   'White wine',
#   'Water',
#   'Vegetable broth',
#   'Fine salt',
#   'Saffron threads'],
#  ['Potatoes',
#   'Flour 00',
#   'Eggs',
#   'Fine salt',
#   'Gorgonzola cheese',
#   'Valtellina Casera cheese',
#   'Fontina cheese',
#   'Emmentaler cheese',
#   'Heavy cream',
#   'Black pepper'],
#  ['Dried cannellini beans',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Rosemary',
#   'Water',
#   'Fine salt',
#   'Black pepper',
#   'Verza (savoy cabbage)',
#   'Italian kale (cavolo nero)',
#   'Chard',
#   'Stale bread',
#   'Extra virgin olive oil',
#   'Peeled tomatoes',
#   'Potatoes',
#   'Onions',
#   'Carrots',
#   'Celery',
#   'Black pepper',
#   'Fine salt',
#   'Peperoncino',
#   'Thyme'],
#  ['Vialone nano rice',
#   'Shallot',
#   'Tomato puree',
#   'Mozzarella cheese',
#   'Marjoram',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Vegetable broth'],
#  ['Green egg lasagna sheets',
#   'Grana Padano DOP cheese',
#   'Thyme',
#   'Oregano',
#   'Whole milk',
#   'Butter',
#   'Flour 00',
#   'Nutmeg',
#   'Fine salt',
#   'Sausage',
#   'Tomato puree',
#   'Celery',
#   'Onions',
#   'Carrots',
#   'Red wine',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Red potatoes',
#   'Flour 00',
#   'Eggs',
#   'Fine salt',
#   'Semolina',
#   'Tomato puree',
#   'Basil',
#   'Garlic',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Mozzarella cheese',
#   'Parmigiano Reggiano DOP cheese'],
#  ['Carnaroli rice',
#   'Shallot',
#   'White wine',
#   'Goatfish',
#   'Clams',
#   'Calamari (squid)',
#   'Shrimps',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Water',
#   'Shallot',
#   'Fennel',
#   'Black peppercorn',
#   'Basil',
#   'Garlic',
#   'Extra virgin olive oil',
#   'Fresh chili pepper',
#   'Basil',
#   'White pepper',
#   'Datterino tomatoes',
#   'Sugar',
#   'Fine salt',
#   'Water',
#   'Garlic',
#   'Parsley',
#   'Extra virgin olive oil'],
#  ['Fusilli pasta',
#   'Eggplant',
#   'Provolone cheese',
#   'Grana Padano DOP cheese',
#   'Sun-dried tomatoes in oil',
#   'Basil',
#   'Whole milk',
#   'Butter',
#   'Flour 00',
#   'Fine salt',
#   'Black pepper',
#   'Vegetable oil'],
#  ['Wholegrain bow tie pasta',
#   'Cherry tomatoes',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Sugar',
#   'Arugula',
#   'Lemon juice',
#   'Extra virgin olive oil',
#   'Pine nuts',
#   'Parmigiano Reggiano DOP cheese',
#   'Fine salt',
#   'Almond flakes',
#   'Lemon peel'],
#  ['Spaghetti',
#   'Tuna',
#   'Swordfish',
#   'Salmon',
#   'Egg yolks',
#   'Parmigiano Reggiano DOP cheese',
#   'White wine',
#   'Garlic',
#   'Thyme',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Bow tie pasta',
#   'Zucchini',
#   'Basil',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Black pepper',
#   'Garlic'],
#  ['Eggplant',
#   'Carnaroli rice',
#   'White wine',
#   'Shallot',
#   'Extra virgin olive oil',
#   'Tomato puree',
#   'Coarse salt',
#   'Vegetable broth',
#   'Parmigiano Reggiano DOP cheese',
#   'Scamorza (provola) cheese',
#   'Basil',
#   'Fine salt',
#   'Black pepper',
#   'Peanut seed oil'],
#  ['Whole grain egg fettuccine pasta',
#   'Cows milk ricotta cheese',
#   'Basil',
#   'Almond flakes',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Flour 00',
#   'Eggs',
#   'Garlic',
#   'Coarse salt',
#   'Extra virgin olive oil',
#   'Basil',
#   'Pecorino cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Pine nuts',
#   'Butter',
#   'Fine salt',
#   'Nutmeg',
#   'Flour 00',
#   'Whole milk',
#   'Parmigiano Reggiano DOP cheese'],
#  ['Sedani Rigati pasta',
#   'Salted ricotta cheese',
#   'Eggplant',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Cluster tomatoes',
#   'Basil',
#   'Fine salt',
#   'Extra virgin olive oil'],
#  ['Rigatoni',
#   'Sun-dried tomatoes in oil',
#   'Pine nuts',
#   'Peeled almonds',
#   'Basil'],
#  ['Flour 00',
#   'Eggs',
#   'Milk',
#   'Flour 00',
#   'Butter',
#   'Salt',
#   'Nutmeg',
#   'Champignon mushrooms',
#   'Cooked ham',
#   'Emmentaler cheese',
#   'Parmigiano Reggiano DOP cheese'],
#  ['Couscous',
#   'Water',
#   'Extra virgin olive oil',
#   'Powdered turmeric',
#   'Fine salt',
#   'Carrots',
#   'Eggplant',
#   'Cherry tomatoes',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Fresh chili pepper',
#   'Spring onions',
#   'Garlic',
#   'Zucchini',
#   'Snap peas',
#   'Fresh ginger',
#   'Mint'],
#  ['Calamarata pasta',
#   'Swordfish',
#   'Extra virgin olive oil',
#   'White wine',
#   'Garlic',
#   'Parsley',
#   'Black pepper',
#   'Fine salt',
#   'Cherry tomatoes',
#   'Extra virgin olive oil',
#   'Capers in vinegar',
#   'Garlic',
#   'Fine salt',
#   'Black pepper'],
#  ['Calamari (squid)',
#   'Paccheri pasta',
#   'Cherry tomatoes',
#   'Tomato puree',
#   'Extra virgin olive oil',
#   'White wine',
#   'Fresh chili pepper',
#   'Garlic',
#   'Parsley',
#   'Fine salt'],
#  ['Strozzapreti pasta',
#   'Celery',
#   'Carrots',
#   'Onions',
#   'Garlic',
#   'Cherry tomatoes',
#   'Tomato puree',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Parsley',
#   'Octopus',
#   'Bay leaves',
#   'Juniper berries',
#   'Garlic',
#   'Pink peppercorn',
#   'Fine salt'],
#  ['Spaghetti',
#   'Garlic',
#   'Fresh chili pepper',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Arborio rice',
#   'Tuna in oil',
#   'Cluster tomatoes',
#   'Caciocavallo cheese',
#   'Cooked ham',
#   'Peas',
#   'Red peppers',
#   'Yellow peppers',
#   'Black olives',
#   'Pickles',
#   'Chives',
#   'Fine salt'],
#  ['Bucatini pasta',
#   'Sardines',
#   'Wild fennel',
#   'Yellow onions',
#   'Raisins',
#   'Pine nuts',
#   'Chopped almonds',
#   'Salted anchovies',
#   'Extra virgin olive oil',
#   'Water',
#   'Saffron',
#   'Fine salt',
#   'Black pepper',
#   'Breadcrumbs',
#   'Extra virgin olive oil'],
#  ['Mini Penne Rigate pasta',
#   'Eggplant',
#   'Canned tomatoes',
#   'Mozzarella cheese',
#   'White onions',
#   'Extra virgin olive oil',
#   'Peanut seed oil',
#   'Fresh chili pepper',
#   'Basil',
#   'Coarse salt',
#   'Fine salt'],
#  ['Casarecce pasta',
#   'Musky octopus',
#   'Eggplant',
#   'Coarse salt',
#   'Shallot',
#   'Extra virgin olive oil',
#   'Cherry tomatoes',
#   'White wine',
#   'Fresh chili pepper',
#   'Parsley',
#   'Fine salt',
#   'Vegetable oil'],
#  ['Spaghetti',
#   'Mussels',
#   'Tomato puree',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Parsley',
#   'Black pepper'],
#  ['Bucatini pasta',
#   'Cooked ham',
#   'Frozen peas',
#   'Garlic',
#   'Extra virgin olive oil',
#   'Peanut seed oil',
#   'Fine salt',
#   'Flour 00',
#   'Butter',
#   'Whole milk',
#   'Fine salt',
#   'Nutmeg',
#   'Water',
#   'Flour 00'],
#  ['Stracchino cheese',
#   'Penne Rigate pasta',
#   'Bresaola',
#   'Cherry tomatoes',
#   'Arugula',
#   'Whole milk',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Casarecce pasta',
#   'Caciocavallo cheese',
#   'Pizzutelli tomatoes',
#   'Taggiasca olives',
#   'Basil',
#   'Ricotta di bufala cheese',
#   'Extra virgin olive oil',
#   'Parmigiano Reggiano DOP cheese',
#   'Sardinian camone tomato',
#   'Fine salt',
#   'Black pepper'],
#  ['Fusilli pasta',
#   'Tomato puree',
#   'Mozzarella cheese',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Basil',
#   'Fine salt',
#   'Parmigiano Reggiano DOP cheese'],
#  ['Gluten-free Spaghetti pasta',
#   'Burrata cheese',
#   'Basil',
#   'Extra virgin olive oil',
#   'Eggplant',
#   'Pine nuts',
#   'Fine salt',
#   'Black pepper',
#   'Peanut seed oil',
#   'Basil'],
#  ['Flour 00',
#   'Water',
#   'Fine salt',
#   'Mussels',
#   'Pecorino Romano cheese',
#   'Garlic',
#   'Dry white wine',
#   'Black pepper',
#   'Parsley',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Bow tie pasta',
#   'Salmon fillets',
#   'Fine salt',
#   'Basil',
#   'Extra virgin olive oil',
#   'Sardinian camone tomato',
#   'Yellow peppers',
#   'Red onions',
#   'Extra virgin olive oil',
#   'Basil',
#   'Fine salt',
#   'Black pepper',
#   'Lemon peel'],
#  ['Wavy lasagna',
#   'Tomato puree',
#   'Yellow onions',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Spinach',
#   'Cows milk ricotta cheese',
#   'Grana Padano DOP cheese',
#   'Garlic',
#   'Fine salt',
#   'Black pepper',
#   'Nutmeg',
#   'Extra virgin olive oil',
#   'Mozzarella cheese',
#   'Grana Padano DOP cheese',
#   'Black pepper',
#   'Fine salt',
#   'Basil'],
#  ['Trofie pasta',
#   'Provola cheese',
#   'Grana Padano DOP cheese',
#   'Sausage',
#   'Tomato puree',
#   'White onions',
#   'White wine',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Butter',
#   'Flour 00',
#   'Whole milk',
#   'Fine salt'],
#  ['Egg Tagliatelle pasta',
#   'Cherry tomatoes',
#   'Eggplant',
#   'Basil',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Water',
#   'Basil',
#   'Pine nuts',
#   'Pecorino cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Wholegrain Penne Rigate pasta',
#   'Cooked ham',
#   'Whipping cream',
#   'Tomato puree',
#   'Parsley',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Black pepper'],
#  ['Paccheri pasta',
#   'Salmon fillets',
#   'Robiola cheese',
#   'Taggiasca olives',
#   'Dry white wine',
#   'Garlic',
#   'Chives',
#   'Lime peel',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'White pepper'],
#  ['Calamarata pasta',
#   'Calamari (squid)',
#   'Garlic',
#   'Fresh chili pepper',
#   'Parsley',
#   'Salt',
#   'Black pepper',
#   'Cherry tomatoes',
#   'Triple concentrated tomato paste',
#   'White wine',
#   'Extra virgin olive oil'],
#  ['Bow tie pasta',
#   'Cherry tomatoes',
#   'Basil',
#   'Olive',
#   'Tuna in oil',
#   'Mozzarella cheese',
#   'Salt',
#   'Pepper',
#   'Extra virgin olive oil'],
#  ['Wholegrain Spaghetti  pasta',
#   'Fresh chili pepper',
#   'Peeled tomatoes',
#   'Black olives',
#   'Fior di latte mozzarella cheese',
#   'Salted capers',
#   'Red onions',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Oregano'],
#  ['Rigatoni',
#   'Tomato puree',
#   'Provola cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Mortadella',
#   'Salami',
#   'Mozzarella cheese',
#   'Eggs',
#   'Onions',
#   'Garlic',
#   'Basil',
#   'Thyme',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Fusilli pasta',
#   'Salmon steaks',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Lemons',
#   'Zucchini',
#   'Extra virgin olive oil',
#   'Pine nuts',
#   'Almonds',
#   'Basil',
#   'Parmigiano Reggiano DOP cheese',
#   'Fine salt'],
#  ['Flour 00',
#   'Eggs',
#   'Eggplant',
#   'Mozzarella cheese',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Tomato puree',
#   'Yellow onions',
#   'Basil',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Whole milk',
#   'Flour 00',
#   'Butter',
#   'Fine salt',
#   'Black pepper',
#   'Grana Padano DOP cheese'],
#  ['Potatoes',
#   'Flour 00',
#   'Eggs',
#   'Fine salt',
#   'Remilled durum wheat semolina',
#   'Speck',
#   'Walnut kernels',
#   'Taleggio cheese',
#   'Whipping cream',
#   'Nutmeg',
#   'Rosemary',
#   'Fine salt',
#   'Black pepper'],
#  ['Rigatoni',
#   'Gorgonzola cheese',
#   'Black olives',
#   'Whipping cream',
#   'Fine salt',
#   'Black pepper'],
#  ['Paccheri pasta',
#   'Champignon mushrooms',
#   'Sausage',
#   'Cows milk ricotta cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Leeks',
#   'Garlic',
#   'White wine',
#   'Extra virgin olive oil',
#   'Triple concentrated tomato paste',
#   'Thyme',
#   'Fine salt',
#   'Black pepper',
#   'Whole milk',
#   'Butter',
#   'Flour 00',
#   'Nutmeg',
#   'Fine salt',
#   'Parmigiano Reggiano DOP cheese'],
#  ['Trofie pasta',
#   'Zucchini',
#   'Smoked pancetta',
#   'Garlic',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Fusilli pasta',
#   'Cherry tomatoes',
#   'Leeks',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Unsalted pistacchios',
#   'Basil',
#   'Water',
#   'Lemon peel',
#   'Parmigiano Reggiano DOP cheese',
#   'Garlic',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Rigatoni',
#   'Eggs',
#   'Parmigiano Reggiano DOP cheese',
#   'Scamorza (provola) cheese',
#   'Pork',
#   'Sausage',
#   'Parmigiano Reggiano DOP cheese',
#   'Bread',
#   'Parsley',
#   'Eggs',
#   'Fine salt',
#   'Black pepper',
#   'Nutmeg',
#   'Tomato puree',
#   'White onions',
#   'Garlic',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Basil',
#   'Black pepper',
#   'Whole milk',
#   'Flour 00',
#   'Butter',
#   'Fine salt',
#   'Nutmeg'],
#  ['Mezze Maniche Rigate pasta',
#   'Tuna in oil',
#   'Tomato puree',
#   'Garlic',
#   'Parsley',
#   'Fresh chili pepper',
#   'Salt',
#   'Extra virgin olive oil',
#   'Anchovies in oil'],
#  ['Red potatoes',
#   'Flour 00',
#   'Eggs',
#   'Fine salt',
#   'Remilled durum wheat semolina',
#   'Red potatoes',
#   'Flour 00',
#   'Fine salt',
#   'Remilled durum wheat semolina'],
#  ['Cluster tomatoes',
#   'Vialone nano rice',
#   'Scamorza (provola) cheese',
#   'Pecorino cheese',
#   'Grana Padano DOP cheese',
#   'Garlic',
#   'Parsley',
#   'Basil',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Spaghetti Quadrati pasta',
#   'Cherry tomatoes',
#   'Tomato paste',
#   'Tomato puree',
#   'Fresh chili pepper',
#   'Red onions',
#   'Basil',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Remilled durum wheat semolina',
#   'Flour 00',
#   'Spinach',
#   'Eggs',
#   'Egg yolks',
#   'Beef',
#   'Pancetta bacon',
#   'Carrots',
#   'Celery',
#   'Yellow onions',
#   'Red wine',
#   'Tomato puree',
#   'Vegetable broth',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Butter',
#   'Flour 00',
#   'Whole milk',
#   'Fine salt',
#   'Nutmeg',
#   'Butter',
#   'Parmigiano Reggiano DOP cheese'],
#  ['Buckwheat flour',
#   'Flour 0',
#   'Water',
#   'Butter',
#   'Dairy cheese',
#   'Grana Padano DOP cheese',
#   'Potatoes',
#   'Garlic',
#   'Verza (savoy cabbage)',
#   'Coarse sea salt'],
#  ['Shell pasta',
#   'Tomato puree',
#   'Parmigiano Reggiano DOP cheese',
#   'Extra virgin olive oil',
#   'Yellow onions',
#   'Fine salt',
#   'Black pepper',
#   'Pork',
#   'Beef',
#   'Cows milk ricotta cheese',
#   'Mozzarella cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Red wine',
#   'Fine salt',
#   'Black pepper',
#   'Eggs',
#   'Garlic'],
#  ['Flour 00',
#   'Eggs',
#   'Egg yolks',
#   'Remilled durum wheat semolina',
#   'Spinach',
#   'Ricotta cheese',
#   'Grana Padano DOP cheese',
#   'Nutmeg',
#   'Fine salt',
#   'Black pepper',
#   'Butter',
#   'Sage'],
#  ['Eggs',
#   'Whole milk',
#   'Flour 00',
#   'Butter',
#   'Beef',
#   'Pork',
#   'Celery',
#   'Carrots',
#   'White onions',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil',
#   'Tomato puree',
#   'Water',
#   'Canned peas',
#   'Smoked scamorza cheese',
#   'White wine',
#   'Butter',
#   'Flour 00',
#   'Fine salt',
#   'Nutmeg',
#   'Whole milk',
#   'Thyme',
#   'Breadcrumbs',
#   'Parmigiano Reggiano DOP cheese'],
#  ['Spaghetti',
#   'Anchovies in oil',
#   'Red onions',
#   'Salted capers',
#   'Taggiasca olives',
#   'Garlic',
#   'Fresh chili pepper',
#   'Parsley',
#   'Breadcrumbs',
#   'Extra virgin olive oil'],
#  ['Whole grain egg fettuccine pasta',
#   'Octopus',
#   'Porcini mushrooms',
#   'Peeled plum tomatoes',
#   'Tomato paste',
#   'Water',
#   'Bay leaves',
#   'Thyme',
#   'Garlic',
#   'Dried chili pepper',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Penne Rigate pasta',
#   'Datterino tomatoes',
#   'Liquid cream',
#   'Vodka',
#   'Garlic',
#   'Yellow onions',
#   'Oregano',
#   'Fresh chili pepper',
#   'Extra virgin olive oil',
#   'Parsley',
#   'Black pepper',
#   'Fine salt',
#   'Parmigiano Reggiano DOP cheese'],
#  ['Ditaloni rigati pasta',
#   'Lentils',
#   'Smoked pancetta',
#   'Tomato puree',
#   'Carrots',
#   'Onions',
#   'Celery',
#   'Vegetable broth',
#   'Fresh garlic',
#   'Rosemary',
#   'Thyme',
#   'Parmigiano Reggiano DOP cheese',
#   'Dried chili pepper',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Rigatoni',
#   'Guanciale',
#   'Sausage',
#   'Pecorino Romano cheese',
#   'Canned cherry tomatoes',
#   'Extra virgin olive oil',
#   'Egg yolks',
#   'Pecorino Romano cheese'],
#  ['Eggs',
#   'Breadcrumbs',
#   'Parmigiano Reggiano DOP cheese',
#   'Lemon peel',
#   'Nutmeg',
#   'Fine salt',
#   'Meat broth'],
#  ['Eggs', 'Flour 00'],
#  ['Spaghetti',
#   'Mussels',
#   'Clams',
#   'Calamari (squid)',
#   'Scampi',
#   'Cherry tomatoes',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Parsley',
#   'White wine',
#   'Fine salt',
#   'Black pepper'],
#  ['Penne Rigate pasta',
#   'Peeled tomatoes',
#   'Garlic',
#   'Dried chili pepper',
#   'Parsley',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Spaghetti',
#   'Peeled tomatoes',
#   'Salted capers',
#   'Parsley',
#   'Anchovies in oil',
#   'Gaeta olives',
#   'Garlic',
#   'Dried chili pepper',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Spaghetti',
#   'Eggs',
#   'Whole milk',
#   'Parmigiano Reggiano DOP cheese',
#   'Smoked scamorza cheese',
#   'Smoked pancetta',
#   'Thyme',
#   'Black pepper',
#   'Extra virgin olive oil',
#   'Garlic'],
#  ['Spaghetti',
#   'Peeled tomatoes',
#   'Guanciale',
#   'Pecorino Romano cheese',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Fresh chili pepper',
#   'White wine'],
#  ['Spaghetti',
#   'Guanciale',
#   'Egg yolks',
#   'Pecorino Romano cheese',
#   'Black pepper'],
#  ['Rigatoni', 'Guanciale', 'Pecorino Romano cheese', 'Fine salt'],
#  ['Paccheri pasta',
#   'Artichokes',
#   'Egg yolks',
#   'Smoked pancetta',
#   'Parmigiano Reggiano DOP cheese',
#   'Pecorino cheese',
#   'Shallot',
#   'White wine',
#   'Extra virgin olive oil',
#   'Black pepper',
#   'Fine salt'],
#  ['Spaghetti', 'Black pepper', 'Pecorino Romano cheese', 'Fine salt'],
#  ['Spaghetti',
#   'Peeled tomatoes',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Basil',
#   'Fine salt'],
#  ['Spaghetti',
#   'Clams',
#   'Garlic',
#   'Parsley',
#   'Extra virgin olive oil',
#   'Black pepper',
#   'Fine salt',
#   'Coarse salt'],
#  ['Flour 00',
#   'Eggs',
#   'Tomato puree',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Fine salt',
#   'Whole milk',
#   'Butter',
#   'Flour 00',
#   'Nutmeg',
#   'Fine salt',
#   'Black pepper',
#   'Sausage',
#   'Pork',
#   'Eggs',
#   'Parmigiano Reggiano DOP cheese',
#   'Extra virgin olive oil',
#   'Onions',
#   'Celery',
#   'Carrots',
#   'Red wine',
#   'Fine salt',
#   'Black pepper',
#   'Parmigiano Reggiano DOP cheese'],
#  ['Potatoes',
#   'Cooked ham',
#   'Edam cheese',
#   'Gorgonzola cheese',
#   'Whipping cream',
#   'Eggs',
#   'Thyme',
#   'Fine salt',
#   'Black pepper'],
#  ['Puff pastry',
#   'Zucchini',
#   'Carrots',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Whole milk',
#   'Flour 00',
#   'Butter',
#   'Nutmeg',
#   'Parmigiano Reggiano DOP cheese',
#   'Eggs',
#   'Fine salt'],
#  ['Stale bread',
#   'Spinach',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Whole milk',
#   'Eggs',
#   'Breadcrumbs',
#   'Grana Padano DOP cheese',
#   'Fine salt',
#   'Nutmeg',
#   'Thyme',
#   'Breadcrumbs',
#   'Eggs',
#   'Fine salt',
#   'Peanut seed oil'],
#  ['Chicken',
#   'Mortadella with pistachio ',
#   'Edam cheese',
#   'Cows milk ricotta cheese',
#   'Grana Padano DOP cheese',
#   'Eggs',
#   'Breadcrumbs',
#   'Marjoram',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Pumpkin',
#   'Breadcrumbs',
#   'Parmigiano Reggiano DOP cheese',
#   'Smoked scamorza cheese',
#   'Eggs',
#   'Sage',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Breadcrumbs',
#   'Vegetable oil'],
#  ['Instant flour for polenta',
#   'Water',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Smoked pancetta',
#   'Smoked scamorza cheese'],
#  ['Beef',
#   'Peas',
#   'Celery',
#   'Carrots',
#   'Yellow onions',
#   'Flour 00',
#   'Dry white wine',
#   'Vegetable broth',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil',
#   'Triple concentrated tomato paste'],
#  ['Veal',
#   'Orange juice',
#   'Oranges',
#   'Butter',
#   'Extra virgin olive oil',
#   'White wine',
#   'Brandy',
#   'Fine salt',
#   'White onions',
#   'Cornstarch',
#   'Water',
#   'Oranges',
#   'Fleur de sel'],
#  ['Luganega sausage',
#   'Potatoes',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Peeled tomatoes',
#   'Oregano',
#   'Rosemary'],
#  ['Desalted cod',
#   'Potatoes',
#   'Tomato puree',
#   'Lemon peel',
#   'Breadcrumbs',
#   'Thyme',
#   'Extra virgin olive oil',
#   'Basil',
#   'Sugar',
#   'Garlic',
#   'Fine salt',
#   'Black pepper',
#   'Red pepper',
#   'White pepper',
#   'Green pepper'],
#  ['Turkey breast',
#   'Emmentaler cheese',
#   'Cooked ham',
#   'Eggs',
#   'Breadcrumbs',
#   'Fine salt',
#   'Black pepper',
#   'Peanut seed oil'],
#  ['Pork ribs',
#   'Yellow mustard powder',
#   'Sweet Paprika',
#   'Cumin',
#   'Peperoncino',
#   'Fine salt',
#   'Garlic powder',
#   'Hot Paprika ',
#   'Worcestershire sauce',
#   'Garlic',
#   'Brown sugar',
#   'Sweet Paprika',
#   'Black pepper',
#   'Maple syrup',
#   'Apple cider vinegar',
#   'Fine salt',
#   'Ketchup',
#   'Mustard',
#   'Extra virgin olive oil',
#   'Yellow onions'],
#  ['Tomini cheese',
#   'Black pepper',
#   'Puff pastry',
#   'Cooked ham',
#   'Thyme',
#   'Egg yolks',
#   'Whipping cream'],
#  ['Pork loin',
#   'Sausage',
#   'Provolone cheese',
#   'Marsala wine',
#   'Porcini mushrooms',
#   'Whipping cream',
#   'Garlic',
#   'Butter',
#   'Extra virgin olive oil',
#   'Sage',
#   'Rosemary',
#   'Water',
#   'Fine salt',
#   'Black pepper',
#   'Flour 00'],
#  ['Veal',
#   'Champignon mushrooms',
#   'Butter',
#   'Black pepper',
#   'Flour 00',
#   'Garlic',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Thyme',
#   'Rosemary'],
#  ['Chicken',
#   'Coarse salt',
#   'Peperoncino',
#   'Sage',
#   'Rosemary',
#   'Garlic',
#   'Extra virgin olive oil'],
#  ['Salmon fillets',
#   'Black pepper',
#   'Almond flakes',
#   'Fresh ginger',
#   'Tabasco®',
#   'Lime peel',
#   'Chives',
#   'Fine salt',
#   'Rice vinegar',
#   'Black pepper',
#   'Piccadilly tomatoes',
#   'Avocado',
#   'Lime juice',
#   'Fine salt'],
#  ['Eggs',
#   'Potatoes',
#   'Parmigiano Reggiano DOP cheese',
#   'Parsley',
#   'Fine salt',
#   'Black pepper',
#   'Vegetable oil'],
#  ['Eggs',
#   'Tomato puree',
#   'Tomini cheese',
#   'Rosemary',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Octopus',
#   'Carrots',
#   'Celery',
#   'Garlic',
#   'Bay leaves',
#   'Ground black pepper',
#   'Fine salt',
#   'Parsley',
#   'Lemon juice',
#   'Extra virgin olive oil',
#   'Black pepper',
#   'Fine salt'],
#  ['Shrimps',
#   'Anchovies',
#   'Goatfish',
#   'Codfish',
#   'Bandfish',
#   'Calamari (squid)',
#   'Semolina',
#   'Fine salt',
#   'Vegetable oil'],
#  ['Bell peppers',
#   'Veal',
#   'Sausage',
#   'Stale bread',
#   'Parmigiano Reggiano DOP cheese',
#   'Pecorino cheese',
#   'Whole milk',
#   'Eggs',
#   'Garlic',
#   'Parsley',
#   'Fine salt',
#   'Black pepper',
#   'Breadcrumbs',
#   'Parmigiano Reggiano DOP cheese',
#   'Extra virgin olive oil'],
#  ['Chicken breast',
#   'Tomato puree',
#   'Mozzarella cheese',
#   'Shallot',
#   'Basil',
#   'Flour 00',
#   'Parmigiano Reggiano DOP cheese',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Puff pastry',
#   'Eggplant',
#   'Scamorza (provola) cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Sun-dried tomatoes in oil',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Squid',
#   'Potatoes',
#   'Bread',
#   'Whole milk',
#   'Fresh scallion',
#   'Parmigiano Reggiano DOP cheese',
#   'Marjoram',
#   'Fresh turmeric',
#   'Eggs',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Natural plain yogurt',
#   'Whipping cream',
#   'Dill',
#   'Extra virgin olive oil'],
#  ['Zucchini',
#   'Scamorza (provola) cheese',
#   'Breadcrumbs',
#   'Grana Padano DOP cheese',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil',
#   'Nutmeg',
#   'Eggs',
#   'Breadcrumbs'],
#  ['Calamari (squid)',
#   'Zucchini',
#   'Potatoes',
#   'Black olives',
#   'Salted capers',
#   'Garlic',
#   'White wine',
#   'Parmigiano Reggiano DOP cheese',
#   'Lemon peel',
#   'Cherry tomatoes',
#   'Parsley',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Fine salt',
#   'Sea bass (sea bass)',
#   'Coarse salt',
#   'Sage',
#   'Thyme',
#   'Parsley',
#   'Dill',
#   'Bay leaves',
#   'Rosemary',
#   'Egg whites',
#   'Garlic',
#   'Lemons'],
#  ['Chicken breast',
#   'Greek yogurt',
#   'Fine salt',
#   'Black pepper',
#   'Caienna pepper',
#   'Powdered turmeric',
#   'Smoked paprika',
#   'Cinnamon powder',
#   'Cumin',
#   'Coriander seeds',
#   'Garlic',
#   'Fresh ginger',
#   'Fresh chili pepper',
#   'White onions',
#   'Coriander',
#   'Extra virgin olive oil',
#   'Basmati rice',
#   'Water',
#   'Cinnamon sticks',
#   'Cardamon',
#   'Star anise',
#   'Coarse salt'],
#  ['Zucchini',
#   'Bread',
#   'Cows milk ricotta cheese',
#   'Eggs',
#   'Grana Padano DOP cheese',
#   'Breadcrumbs',
#   'Flour 00',
#   'Fine salt',
#   'Black pepper',
#   'Tomato puree',
#   'Garlic',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Mozzarella cheese',
#   'Basil'],
#  ['Prawns',
#   'Lemon juice',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Parsley'],
#  ['Prawns',
#   'Peeled tomatoes',
#   'Water',
#   'Brandy',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Fresh chili pepper',
#   'Parsley',
#   'Fine salt',
#   'Black pepper'],
#  ['Octopus',
#   'Tomato puree',
#   'Shallot',
#   'Garlic',
#   'Thyme',
#   'Sage',
#   'Water',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Beef filet',
#   'Green peppercorns',
#   'Heavy cream',
#   'Dijon mustard',
#   'Meat broth',
#   'Brandy',
#   'Clarified butter',
#   'Salt',
#   'Flour 00'],
#  ['Round zucchini',
#   'Pork',
#   'Pork sausage',
#   'Eggs',
#   'Parmigiano Reggiano DOP cheese',
#   'Parsley',
#   'Black pepper',
#   'Bread',
#   'Fine salt',
#   'Extra virgin olive oil'],
#  ['Swordfish',
#   'Basil',
#   'Cluster tomatoes',
#   'Green Peperoncino',
#   'Garlic',
#   'Basil',
#   'Green olives',
#   'Salted capers',
#   'Breadcrumbs',
#   'Cluster tomatoes',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Eggs', 'Whole milk', 'Fine salt', 'Extra virgin olive oil'],
#  ['Potatoes',
#   'Carrots',
#   'Green beans',
#   'Zucchini',
#   'Leeks',
#   'Parmigiano Reggiano DOP cheese',
#   'Eggs',
#   'Garlic',
#   'Parsley',
#   'Extra virgin olive oil',
#   'Nutmeg',
#   'Black pepper',
#   'Fine salt',
#   'Breadcrumbs',
#   'Eggs',
#   'Peanut seed oil'],
#  ['Chicken breast',
#   'Red peppers',
#   'Yellow peppers',
#   'Peeled baby plum tomatoes',
#   'Butter',
#   'Shallot',
#   'White wine',
#   'Water',
#   'Flour 00',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Chicken',
#   'Mozzarella cheese',
#   'Breadcrumbs',
#   'Parmigiano Reggiano DOP cheese',
#   'Eggs',
#   'Oregano',
#   'Fine salt',
#   'Black pepper',
#   'Eggs',
#   'Breadcrumbs',
#   'Vegetable oil'],
#  ['Chicken drumsticks',
#   'Smoked pancetta',
#   'Mustard',
#   'Garlic',
#   'Rosemary',
#   'Sage',
#   'White wine',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Veal sirloin',
#   'Cooked ham',
#   'Smoked provola cheese',
#   'Sage',
#   'Extra virgin olive oil',
#   'Black pepper',
#   'Butter',
#   'Fine salt',
#   'White wine',
#   'Thyme',
#   'Rosemary',
#   'Flour 00',
#   'Water'],
#  ['Veal',
#   'Parsley',
#   'Butter',
#   'Flour 00',
#   'Dry white wine',
#   'Vegetable broth',
#   'Fine salt',
#   'Black pepper'],
#  ['Entrecôte',
#   'Arugula',
#   'Cherry tomatoes',
#   'Salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Precooked chickpeas',
#   'Eggs',
#   'Mustard',
#   'Shallot',
#   'Fresh ginger',
#   'Sandwich bread',
#   'Fine salt',
#   'Black pepper',
#   'Breadcrumbs',
#   'Hamburger muffins',
#   'Salad',
#   'Tomatoes',
#   'Ketchup',
#   'Mayonnaise'],
#  ['Chicken breast',
#   'Rosemary',
#   'Lemon juice',
#   'Lemon peel',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Smoked paprika',
#   'Soy milk',
#   'Rice vinegar',
#   'Wasabi',
#   'Chives',
#   'Tabasco®',
#   'Fine salt',
#   'Dijon mustard',
#   'Acacia honey',
#   'Vegetable oil',
#   'Flour 00',
#   'Corn flakes',
#   'Eggs',
#   'Rosemary',
#   'Vegetable oil'],
#  ['Veal sirloin',
#   'Potatoes',
#   'White wine',
#   'Rosemary',
#   'Garlic',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper'],
#  ['Octopus',
#   'Potatoes',
#   'Bay leaves',
#   'Parsley',
#   'Black pepper',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Lemon juice'],
#  ['Salmon steaks',
#   'Potatoes',
#   'Lemon peel',
#   'Lemon juice',
#   'White wine',
#   'Extra virgin olive oil',
#   'Parsley',
#   'Fine salt',
#   'Black pepper'],
#  ['Eggplant',
#   'Pork',
#   'Tomato puree',
#   'Onions',
#   'Stale bread',
#   'Pecorino cheese',
#   'Garlic',
#   'White wine',
#   'Extra virgin olive oil',
#   'Basil',
#   'Black pepper',
#   'Fine salt',
#   'Coarse salt'],
#  ['Swordfish',
#   'Cherry tomatoes',
#   'Green olives',
#   'Extra virgin olive oil',
#   'Garlic',
#   'Pine nuts',
#   'Oregano',
#   'Fine salt',
#   'Black pepper'],
#  ['Salmon fillets',
#   'Bread',
#   'Parsley',
#   'Dill',
#   'Thyme',
#   'Rosemary',
#   'Lemon peel',
#   'Extra virgin olive oil',
#   'Ground white pepper',
#   'Fine salt'],
#  ['Chicken',
#   'Pomodori di Pachino (cherry tomatoes)',
#   'Black olives',
#   'Capers in vinegar',
#   'Garlic',
#   'Fresh chili pepper',
#   'Wild fennel',
#   'Rose wine',
#   'Water',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Chicken breast',
#   'Green olives',
#   'Pickles',
#   'Red peppers',
#   'White celery',
#   'Carrots',
#   'Gruyere cheese',
#   'Fine salt',
#   'Black pepper',
#   'Mustard',
#   'Fine salt',
#   'White wine vinegar',
#   'Extra virgin olive oil',
#   'Mayonnaise'],
#  ['Precooked cotechino',
#   'Dried lentils',
#   'Celery',
#   'Carrots',
#   'White onions',
#   'Extra virgin olive oil',
#   'Bay leaves',
#   'Rosemary',
#   'Vegetable broth',
#   'Fine salt',
#   'Black pepper'],
#  ['Sheeps milk ricotta cheese',
#   'Homemade bread',
#   'Pecorino cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Eggs',
#   'Garlic',
#   'Parsley',
#   'Fine salt',
#   'Black pepper',
#   'Tomato puree',
#   'Garlic',
#   'Basil',
#   'Extra virgin olive oil',
#   'Salt',
#   'Black pepper'],
#  ['Puff pastry',
#   'Precooked cotechino',
#   'Lentils',
#   'Carrots',
#   'Onions',
#   'Celery',
#   'Rosemary',
#   'Extra virgin olive oil',
#   'Butter',
#   'Fine salt',
#   'Black pepper',
#   'Vegetable broth',
#   'Heavy cream',
#   'Egg yolks'],
#  ['Sea bream',
#   'Garlic',
#   'Fine salt',
#   'Black pepper',
#   'Parsley',
#   'Thyme',
#   'Extra virgin olive oil',
#   'Lemons'],
#  ['Potatoes',
#   'Fior di latte mozzarella cheese',
#   'Neapolitan salami',
#   'Cooked ham',
#   'Parmigiano Reggiano DOP cheese',
#   'Eggs',
#   'Extra virgin olive oil',
#   'Black pepper',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Breadcrumbs',
#   'Parmigiano Reggiano DOP cheese'],
#  ['Black eggplants',
#   'Tomato puree',
#   'Fior di latte mozzarella cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Yellow onions',
#   'Extra virgin olive oil',
#   'Black pepper',
#   'Basil',
#   'Fine salt',
#   'Peanut seed oil',
#   'Coarse salt'],
#  ['Chicken',
#   'Peeled tomatoes',
#   'Yellow onions',
#   'Carrots',
#   'Celery',
#   'Garlic',
#   'Red wine',
#   'Extra virgin olive oil',
#   'Rosemary',
#   'Parsley',
#   'Fine salt',
#   'Black pepper'],
#  ['Veal marrow bones',
#   'Meat broth',
#   'Yellow onions',
#   'Flour 00',
#   'White wine',
#   'Extra virgin olive oil',
#   'Butter',
#   'Fine salt',
#   'Black pepper',
#   'Parsley',
#   'Garlic',
#   'Lemon peel'],
#  ['Beef',
#   'Barolo wine',
#   'Carrots',
#   'Celery',
#   'Yellow onions',
#   'Garlic',
#   'Rosemary',
#   'Bay leaves',
#   'Cloves',
#   'Ground black pepper',
#   'Cinnamon sticks',
#   'Butter',
#   'Extra virgin olive oil',
#   'Fine salt'],
#  ['Eggs',
#   'Pecorino cheese',
#   'Parmigiano Reggiano DOP cheese',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Beef',
#   'Sausage',
#   'Bread',
#   'Pecorino cheese',
#   'Whole milk',
#   'Eggs',
#   'Thyme',
#   'Nutmeg',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil',
#   'Red potatoes',
#   'Shallot',
#   'Sage',
#   'Thyme',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Chicken wings',
#   'Potatoes',
#   'Breadcrumbs',
#   'Flour 00',
#   'Parmigiano Reggiano DOP cheese',
#   'Eggs',
#   'Parsley',
#   'Extra virgin olive oil',
#   'Fine salt'],
# ...
#   'Vegetable oil',
#   'Flour 00',
#   'Fine salt',
#   'Sugar',
#   'Eggs',
#   'Walnuts',
#   'Vanilla bean'],
#  ['Digestive biscuits',
#   'Butter',
#   'Nutella',
#   'Cream cheese',
#   'Chopped hazelnuts'],
#  ['Coffee',
#   'Sugar',
#   'Water',
#   'Heavy cream',
#   'Heavy cream',
#   'Unsweetened cocoa powder'],
#  ['Mascarpone cheese',
#   'Egg yolks',
#   'Water',
#   'Sugar',
#   'Strawberries',
#   'Ladyfingers',
#   'Sugar',
#   'Lemon juice',
#   'Strawberries'],
#  ['Butter',
#   'Flour 00',
#   'Fresh brewers yeast',
#   'Sugar',
#   'Vanilla bean',
#   'Lemon peel',
#   'Fine salt',
#   'Eggs',
#   'Whole milk',
#   'Eggs',
#   'Granulated sugar'],
#  ['Unsweetened cocoa powder',
#   'Honey',
#   'Eggs',
#   'Sugar',
#   'Flour 00',
#   'Vanilla bean',
#   'Condensed milk',
#   'Heavy cream',
#   'Gelatin',
#   'Honey',
#   'Vanilla extract'],
#  ['Fuji Apples',
#   'Flour 00',
#   'Cows milk ricotta cheese',
#   'Acacia honey',
#   'Eggs',
#   'Baking powder',
#   'Lemon peel',
#   'Orange peel',
#   'Sugar',
#   'Whole milk',
#   'Vegetable oil'],
#  ['Heavy cream', 'Milk', 'Egg yolks', 'Sugar', 'Vanilla bean', 'Sugar'],
#  ['Ladyfingers',
#   'Raspberries',
#   'Mascarpone cheese',
#   'Heavy cream',
#   'Powdered sugar',
#   'Vanilla bean',
#   'Strawberries',
#   'Raspberries',
#   'Lemon juice',
#   'Brown sugar',
#   'Wildflower honey',
#   'Vanilla bean',
#   'Berries',
#   'Mint'],
#  ['Egg whites',
#   'Egg yolks',
#   'Sugar',
#   'Butter',
#   'Unsweetened cocoa powder',
#   'Flour 00',
#   'Potato starch'],
#  ['Eggs', 'Flour 00', 'Powdered sugar', 'Butter', 'Lemon peel'],
#  ['Heavy cream',
#   'Mascarpone cheese',
#   'Coffee',
#   'Ladyfingers',
#   'Unsweetened cocoa powder',
#   'Powdered sugar'],
#  ['Puff pastry',
#   'Butter',
#   'Sugar',
#   'Cows milk ricotta cheese',
#   'Heavy cream',
#   'Powdered sugar',
#   'Coffee',
#   'Dark chocolate chips',
#   'Powdered sugar',
#   'Coffee beans'],
#  ['Dark chocolate',
#   'Sugar',
#   'Butter',
#   'Unsweetened cocoa powder',
#   'Eggs',
#   'Vanilla extract',
#   'Fine salt',
#   'Powdered sugar'],
#  ['Golden delicious apples',
#   'Mascarpone cheese',
#   'Flour 00',
#   'Sugar',
#   'Eggs',
#   'Baking powder',
#   'Vanilla bean',
#   'Fine salt',
#   'Butter',
#   'Flour 00'],
#  ['Water',
#   'Whole milk',
#   'Butter',
#   'Fine salt',
#   'Sugar',
#   'Flour 00',
#   'Eggs',
#   'Egg yolks',
#   'Water',
#   'Heavy cream',
#   'Powdered sugar',
#   'Vanilla bean',
#   'Water',
#   'Dark chocolate',
#   'Heavy cream',
#   'Sugar',
#   'Salt'],
#  ['Eggs', 'Sugar', 'Vanilla bean', 'Flour 00', 'Potato starch', 'Fine salt'],
#  ['Eggs',
#   'Flour 00',
#   'Potato starch',
#   'Sugar',
#   'Fine salt',
#   'Vanilla bean',
#   'Whole milk',
#   'Heavy cream',
#   'Egg yolks',
#   'Cornstarch',
#   'Sugar',
#   'Vanilla bean',
#   'Dark chocolate',
#   'Alchermes',
#   'Unsweetened cocoa powder'],
#  ['Sugar',
#   'Flour 00',
#   'Water',
#   'Sunflower seed oil',
#   'Eggs',
#   'Vanilla bean',
#   'Lemon peel',
#   'Baking powder',
#   'Cream of tartar',
#   'Fine salt',
#   'Powdered sugar'],
#  ['Heavy cream', 'Vanilla bean', 'Gelatin', 'Sugar'],
#  ['Eggs',
#   'Egg yolks',
#   'Sugar',
#   'Flour 00',
#   'Potato starch',
#   'Vanilla bean',
#   'Lemon peel',
#   'Heavy cream',
#   'Sugar',
#   'Lemon peel',
#   'Water',
#   'Sugar',
#   'Limoncello',
#   'Lemon peel',
#   'Egg yolks',
#   'Sugar',
#   'Lemon juice',
#   'Butter',
#   'Vanilla bean',
#   'Lemon peel',
#   'Whole milk',
#   'Heavy cream',
#   'Egg yolks',
#   'Sugar',
#   'Cornstarch',
#   'Vanilla bean',
#   'Fine salt',
#   'Lemon peel',
#   'Limoncello',
#   'Whole milk'],
#  ['Flour 00',
#   'Sugar',
#   'Eggs',
#   'Vegetable oil',
#   'Lemon juice',
#   'Lemon peel',
#   'Baking powder',
#   'Fine salt',
#   'Butter',
#   'Powdered sugar'],
#  ['Manitoba flour',
#   'Whole milk',
#   'Butter',
#   'Sugar',
#   'Brewers yeast',
#   'Eggs',
#   'Lemon peel',
#   'Vanilla bean',
#   'Fine salt',
#   'Water',
#   'Whole milk',
#   'Heavy cream',
#   'Egg yolks',
#   'Sugar',
#   'Cornstarch',
#   'Lemon peel',
#   'Vanilla bean',
#   'Eggs',
#   'Whole milk',
#   'Powdered sugar'],
#  ['Flour 00',
#   'Eggs',
#   'Butter',
#   'Sugar',
#   'Lemon peel',
#   'Fine salt',
#   'Baking powder',
#   'Black cherries in syrup',
#   'Whole milk',
#   'Egg yolks',
#   'Sugar',
#   'Flour 00',
#   'Lemon peel',
#   'Powdered sugar'],
#  ['Dark chocolate',
#   'Unsweetened cocoa powder',
#   'Flour 00',
#   'Sugar',
#   'Eggs',
#   'Butter',
#   'Baking powder',
#   'Fine salt'],
#  ['Flour 00',
#   'Sugar',
#   'Eggs',
#   'Unsweetened cocoa powder',
#   'Vanilla extract',
#   'Nutella',
#   'Dark chocolate'],
#  ['Whole milk',
#   'Heavy cream',
#   'Sugar',
#   'Eggs',
#   'Egg yolks',
#   'Vanilla bean',
#   'Sugar'],
#  ['Strawberries',
#   'Eggs',
#   'Flour 00',
#   'Butter',
#   'Sugar',
#   'Lemon juice',
#   'Baking powder',
#   'Strawberries',
#   'Strawberry jam',
#   'Heavy cream',
#   'Powdered sugar',
#   'Strawberries'],
#  ['Manitoba flour',
#   'Sugar',
#   'Fresh brewers yeast',
#   'Orange peel',
#   'Lemon peel',
#   'Vanilla bean',
#   'Fine salt',
#   'Water',
#   'Manitoba flour',
#   'Eggs',
#   'Rum ',
#   'Butter',
#   'Candied orange',
#   'Raisins',
#   'Peeled almonds',
#   'Whole peeled hazelnuts',
#   'Brown sugar',
#   'Cornstarch',
#   'Fioretto corn flour ',
#   'Egg whites',
#   'Granulated sugar',
#   'Almonds'],
#  ['Butter', 'Powdered sugar', 'Egg whites', 'Flour 0'],
#  ['Flour 00',
#   'Lard',
#   'Butter',
#   'Sugar',
#   'Wildflower honey',
#   'Eggs',
#   'Whole milk',
#   'Lemon peel',
#   'Orange peel',
#   'Fine salt',
#   'Cooked wheat',
#   'Whole milk',
#   'Butter',
#   'Lemon peel',
#   'Orange peel',
#   'Fine salt',
#   'Sheeps milk ricotta cheese',
#   'Sugar',
#   'Candied citron',
#   'Wildflower honey',
#   'Eggs',
#   'Egg yolks',
#   'Orange blossom water',
#   'Whole milk',
#   'Orange peel',
#   'Lemon peel',
#   'Powdered sugar'],
#  ['Bananas',
#   'Flour 00',
#   'Butter',
#   'Sugar',
#   'Eggs',
#   'Cinnamon powder',
#   'Baking powder',
#   'Baking soda',
#   'Lemon juice',
#   'Fine salt'],
#  ['Eggs',
#   'Egg yolks',
#   'Butter',
#   'Water',
#   'Flour 00',
#   'Fine salt',
#   'Egg yolks',
#   'Cornstarch',
#   'Vanilla bean',
#   'Sugar',
#   'Whole milk',
#   'Heavy cream',
#   'Black cherries in syrup',
#   'Peanut seed oil',
#   'Powdered sugar'],
#  ['Whole milk',
#   'Eggs',
#   'Flour 00',
#   'Sugar',
#   'Butter',
#   'Baking powder',
#   'Lemon peel',
#   'Fine salt'],
#  ['Flour 00',
#   'Butter',
#   'Sugar',
#   'Egg yolks',
#   'Orange marmelade',
#   'Powdered sugar'],
#  ['Eggs', 'Flour 00', 'Whole milk', 'Butter'],
#  ['Sugar',
#   'Flour 00',
#   'Potato starch',
#   'Eggs',
#   'Vanilla bean',
#   'Fine salt',
#   'Egg yolks',
#   'Sugar',
#   'Whole milk',
#   'Heavy cream',
#   'Cornstarch',
#   'Vanilla bean',
#   'Heavy cream',
#   'Powdered sugar',
#   'Water',
#   'Sugar',
#   'Grand Marnier liqueur',
#   'Powdered sugar'],
#  ['Digestive biscuits',
#   'Brown sugar',
#   'Butter',
#   'Natural plain yogurt',
#   'Gelatin',
#   'Whole milk',
#   'Heavy cream',
#   'Powdered sugar',
#   'Berries'],
#  ['Dark chocolate 55%',
#   'Whole milk',
#   'Vanilla bean',
#   'Egg yolks',
#   'Sugar',
#   'Cornstarch',
#   'Fine salt'],
#  ['Whole milk',
#   'Flour 00',
#   'Brewers yeast',
#   'Potatoes',
#   'Manitoba flour',
#   'Flour 00',
#   'Eggs',
#   'Sugar',
#   'Butter',
#   'Acacia honey',
#   'Lemon peel',
#   'Fine salt',
#   'Butter',
#   'Peanut seed oil',
#   'Sugar'],
#  ['Flour 00',
#   'Dark chocolate 55%',
#   'Sugar',
#   'Butter',
#   'Eggs',
#   'Unsweetened cocoa powder',
#   'Baking powder',
#   'Fine salt',
#   'Dark chocolate 55%',
#   'Heavy cream',
#   'Whole peeled hazelnuts',
#   'Sugar',
#   'Dark chocolate 55%',
#   'Water',
#   'Sugar',
#   'Acacia honey',
#   'Powdered sugar',
#   'Water'],
#  ['Flour 00',
#   'Sugar',
#   'Butter',
#   'Grappa',
#   'Eggs',
#   'Baking powder',
#   'Vanilla bean',
#   'Egg yolks',
#   'Fine salt',
#   'Peanut seed oil',
#   'Powdered sugar'],
#  ['Eggs',
#   'Egg yolks',
#   'Sugar',
#   'Fine salt',
#   'Vanilla bean',
#   'Lemon peel',
#   'Almond flour',
#   'Flour 00',
#   'Baking powder',
#   'Fioretto corn flour ',
#   'Butter',
#   'Butter',
#   'Almond flour'],
#  ['Nutella', 'Flour 00', 'Eggs', 'Nutella', 'Chopped hazelnuts'],
#  ['Eggs',
#   'Flour 00',
#   'Sugar',
#   'Butter',
#   'Lemon peel',
#   'Whole milk',
#   'Eggs',
#   'Egg yolks',
#   'Sugar',
#   'Cornstarch',
#   'Flour 00',
#   'Lemon peel',
#   'Pine nuts',
#   'Powdered sugar'],
#  ['Whole milk',
#   'Sugar',
#   'Butter',
#   'Flour 00',
#   'Eggs',
#   'Water',
#   'Vanilla extract',
#   'Lemon juice',
#   'Fine salt',
#   'Powdered sugar',
#   'Butter'],
#  ['Dark chocolate', 'Butter', 'Eggs', 'Sugar', 'Flour 00', 'Powdered sugar'],
#  ['Blanched almonds', 'Sugar', 'Acacia honey', 'Lemon juice'],
#  ['Pandoro cake',
#   'Powdered sugar',
#   'Cows milk ricotta cheese',
#   'Dark chocolate',
#   'Oranges',
#   'Powdered sugar',
#   'Dark chocolate',
#   'Heavy cream'],
#  ['Sugar',
#   'Flour 00',
#   'Butter',
#   'Orange peel',
#   'Eggs',
#   'Egg yolks',
#   'Fine salt',
#   'Anise liqueur',
#   'Colored sprinkles',
#   'Wildflower honey',
#   'Candied orange',
#   'Candied citron',
#   'Food decorations',
#   'Candied cherries',
#   'Peanut seed oil'],
#  ['Powdered sugar',
#   'Flour 00',
#   'Egg yolks',
#   'Butter',
#   'Lemon peel',
#   'Cows milk ricotta cheese',
#   'Sugar',
#   'Egg yolks',
#   'Dark chocolate chips',
#   'Orange peel',
#   'Cinnamon powder'],
#  ['Cornstarch',
#   'Flour 00',
#   'Butter',
#   'Sugar',
#   'Eggs',
#   'Lemon juice',
#   'Baking powder',
#   'Lemon peel',
#   'Powdered sugar'],
#  ['Dark chocolate',
#   'Cookies',
#   'Butter',
#   'Sugar',
#   'Eggs',
#   'Rum ',
#   'Powdered sugar'],
#  ['Dark chocolatel 50%',
#   'Peeled almonds',
#   'Whole peeled hazelnuts',
#   'Powdered sugar',
#   'Butter',
#   'Potato starch',
#   'Unsweetened cocoa powder',
#   'Egg whites',
#   'Egg yolks',
#   'Baking powder',
#   'Vanilla bean',
#   'Fine salt',
#   'Powdered sugar'],
#  ['Egg yolks', 'Sugar', 'Vin santo wine'],
#  ['Flour 00',
#   'Sugar',
#   'Lard',
#   'Unsweetened cocoa powder',
#   'Fine salt',
#   'Eggs',
#   'White wine vinegar',
#   'Marsala wine',
#   'Sheeps milk ricotta cheese',
#   'Sugar',
#   'Dark chocolate chips',
#   'Eggs',
#   'Vegetable oil',
#   'Candied cherries',
#   'Powdered sugar',
#   'Ground pistacchio',
#   'Candied orange'],
#  ['Whole milk',
#   'Sugar',
#   'Egg yolks',
#   'Rice starch',
#   'Vanilla bean',
#   'Lemon peel'],
#  ['Flour 00',
#   'Butter',
#   'Powdered sugar',
#   'Egg yolks',
#   'Acacia honey',
#   'Lemon peel',
#   'Vanilla bean',
#   'Fine salt',
#   'Apricot jam',
#   'Lemon peel'],
#  ['Water',
#   'Flour 00',
#   'Sugar',
#   'Lemon peel',
#   'Wildflower honey',
#   'Orange peel',
#   'Colored sprinkles',
#   'Vegetable oil',
#   'Vegetable oil'],
#  ['Ladyfingers',
#   'Eggs',
#   'Mascarpone cheese',
#   'Sugar',
#   'Coffee',
#   'Unsweetened cocoa powder'],
#  ['Manitoba flour',
#   'Fresh brewers yeast',
#   'Malt',
#   'Whole milk',
#   'Manitoba flour',
#   'Flour 00',
#   'Fresh brewers yeast',
#   'Eggs',
#   'Sugar',
#   'Butter',
#   'Flour 00',
#   'Eggs',
#   'Egg yolks',
#   'Sugar',
#   'Butter',
#   'Lemon peel',
#   'Vanilla bean',
#   'Candied orange',
#   'Candied citron',
#   'Raisins',
#   'Fine salt',
#   'Butter'],
#  ['Manitoba flour',
#   'Whole milk',
#   'Brewers yeast',
#   'Flour 0',
#   'Whole milk',
#   'Butter',
#   'Sugar',
#   'Eggs',
#   'Egg yolks',
#   'Brewers yeast',
#   'Fine salt',
#   'Malt',
#   'Cream cheese',
#   'Fresh liquid cream',
#   'Fine salt',
#   'Black pepper',
#   'Chives',
#   'Smoked Salmon',
#   'Asparagus',
#   'Robiola cheese',
#   'Fine salt',
#   'Black pepper',
#   'Goat',
#   'Tomato paste',
#   'Fresh liquid cream',
#   'Radicchio',
#   'Prosciutto cotto',
#   'Black pepper',
#   'Fine salt',
#   'Shrimps',
#   'Chives',
#   'Cocktail sauce'],
#  ['Flour 0',
#   'Sugar',
#   'Fresh brewers yeast',
#   'Lemon peel',
#   'Vanilla bean',
#   'Water',
#   'Egg yolks',
#   'Fine salt',
#   'Butter',
#   'Egg yolks',
#   'Fresh liquid cream'],
#  ['Flour 00',
#   'Butter',
#   'Cinnamon powder',
#   'Fine salt',
#   'Flour 00',
#   'Brown sugar',
#   'Whole milk',
#   'Liquid sourdough starter',
#   'Water',
#   'Fresh brewers yeast',
#   'Cinnamon powder',
#   'Butter',
#   'Brown sugar',
#   'Heavy cream',
#   'Vegetable oil'],
#  ['Flour 0',
#   'Water',
#   'Brewers yeast',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Tomato puree',
#   'Caper berries',
#   'Anchovies in oil',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Oregano',
#   'Black pepper'],
#  ['Zucchini',
#   'Parmigiano Reggiano DOP cheese',
#   'Flour 00',
#   'Brewers yeast',
#   'Water',
#   'Fine salt',
#   'Peanut seed oil',
#   'Fine salt'],
#  ['Water',
#   'Fresh brewers yeast',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Barley malt',
#   'Semolina',
#   'Flour 00',
#   'Extra virgin olive oil'],
#  ['Eggs',
#   'Manitoba flour',
#   'Fine salt',
#   'Sugar',
#   'Butter',
#   'Fresh brewers yeast',
#   'Water',
#   'Sugar',
#   'Rum '],
#  ['Manitoba flour',
#   'Water',
#   'Fresh brewers yeast',
#   'Flour 00',
#   'Whole milk',
#   'Butter',
#   'Fine salt',
#   'Sugar',
#   'Zucchini',
#   'Caciocavallo cheese',
#   'Almond flakes',
#   'Shallot',
#   'Thyme',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Black pepper',
#   'Water',
#   'Extra virgin olive oil'],
#  ['Butter',
#   'Flour 00',
#   'Fresh brewers yeast',
#   'Sugar',
#   'Vanilla bean',
#   'Lemon peel',
#   'Fine salt',
#   'Eggs',
#   'Whole milk',
#   'Eggs',
#   'Granulated sugar'],
#  ['Flour 00',
#   'Water',
#   'Baking powder',
#   'Fine salt',
#   'Mozzarella cheese',
#   'Canned tomatoes',
#   'Oregano',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil'],
#  ['Water',
#   'Flour 00',
#   'Extra virgin olive oil',
#   'Brewers yeast',
#   'Fine salt',
#   'Malt',
#   'Tomato puree',
#   'Basil',
#   'Mozzarella cheese',
#   'Cooked ham',
#   'Extra virgin olive oil'],
#  ['Flour 2', 'Raisins', 'Water', 'Water', 'Flour 1', 'Water', 'Flour 1'],
#  ['Manitoba flour',
#   'Whole milk',
#   'Butter',
#   'Sugar',
#   'Brewers yeast',
#   'Eggs',
#   'Lemon peel',
#   'Vanilla bean',
#   'Fine salt',
#   'Water',
#   'Whole milk',
#   'Heavy cream',
#   'Egg yolks',
#   'Sugar',
#   'Cornstarch',
#   'Lemon peel',
#   'Vanilla bean',
#   'Eggs',
#   'Whole milk',
#   'Powdered sugar'],
#  ['Manitoba flour',
#   'Sugar',
#   'Fresh brewers yeast',
#   'Orange peel',
#   'Lemon peel',
#   'Vanilla bean',
#   'Fine salt',
#   'Water',
#   'Manitoba flour',
#   'Eggs',
#   'Rum ',
#   'Butter',
#   'Candied orange',
#   'Raisins',
#   'Peeled almonds',
#   'Whole peeled hazelnuts',
#   'Brown sugar',
#   'Cornstarch',
#   'Fioretto corn flour ',
#   'Egg whites',
#   'Granulated sugar',
#   'Almonds'],
#  ['Whole milk',
#   'Manitoba flour',
#   'Extra virgin olive oil',
#   'Sugar',
#   'Eggs',
#   'Fine salt',
#   'Fresh brewers yeast',
#   'Cooked ham',
#   'Scamorza (provola) cheese',
#   'Whole milk',
#   'Egg yolks'],
#  ['Whole milk',
#   'Flour 00',
#   'Brewers yeast',
#   'Potatoes',
#   'Manitoba flour',
#   'Flour 00',
#   'Eggs',
#   'Sugar',
#   'Butter',
#   'Acacia honey',
#   'Lemon peel',
#   'Fine salt',
#   'Butter',
#   'Peanut seed oil',
#   'Sugar'],
#  ['Raisins',
#   'Manitoba flour',
#   'Flour 0',
#   'Water',
#   'Water',
#   'Manitoba flour',
#   'Flour 0',
#   'Flour 00',
#   'Water',
#   'Sugar'],
#  ['Manitoba flour',
#   'Flour 00',
#   'Water',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Fresh brewers yeast',
#   'Canned tomatoes',
#   'Fior di latte mozzarella cheese',
#   'Oregano',
#   'Fine salt',
#   'Basil',
#   'Extra virgin olive oil'],
#  ['Manitoba flour',
#   'Flour 00',
#   'Water',
#   'Fresh brewers yeast',
#   'Fine salt',
#   'Malt'],
#  ['Lard',
#   'Flour 0',
#   'Sugar',
#   'Fine salt',
#   'Water',
#   'Whole milk',
#   'Baking powder',
#   'Vegetable oil'],
#  ['Manitoba flour',
#   'Flour 00',
#   'Fresh brewers yeast',
#   'Whole milk',
#   'Butter',
#   'Sugar',
#   'Fine salt',
#   'Eggs',
#   'Whole milk'],
#  ['Water',
#   'Flour 00',
#   'Fine salt',
#   'Fresh brewers yeast',
#   'Ricotta di bufala cheese',
#   'Water',
#   'Fior di latte mozzarella cheese',
#   'Mortadella',
#   'Black pepper',
#   'Basil',
#   'Peanut seed oil'],
#  ['Water',
#   'Flour 00',
#   'Fresh brewers yeast',
#   'Sugar',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Tomato puree',
#   'Mozzarella cheese',
#   'Fine salt',
#   'Black pepper',
#   'Extra virgin olive oil',
#   'Oregano'],
#  ['Flour 00',
#   'Water',
#   'Extra virgin olive oil',
#   'Fine salt',
#   'Fresh brewers yeast',
#   'Salt',
#   'Rosemary',
#   'Extra virgin olive oil',
#   'Water',
#   'Extra virgin olive oil'],
#  ['Flour 00',
#   'Manitoba flour',
#   'Water',
#   'Extra virgin olive oil',
#   'Fresh brewers yeast',
#   'Sugar',
#   'Fine salt',
#   'Fior di latte mozzarella cheese',
#   'Tomato puree',
#   'Fine salt',
#   'Oregano',
#   'Extra virgin olive oil',
#   'Vegetable oil'],
#  ['Flour 00',
#   'Manitoba flour',
#   'Water',
#   'Fine salt',
#   'Malt',
#   'Fresh brewers yeast',
#   'Extra virgin olive oil',
#   'Extra virgin olive oil',
#   'Extra virgin olive oil',
#   'Salt',
#   'Water'],
#  ['Manitoba flour',
#   'Water',
#   'Fine salt',
#   'Extra virgin olive oil',
#   'Extra virgin olive oil',
#   'Crescenza cheese']]

# %%
import pickle
with open('giallo_ingredients.pkl', 'wb') as handle:
    pickle.dump(list_of_list_ing, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# with open('tasty_ingredients.pkl', 'rb') as handle:
#     recipes_ingredients = pickle.load(handle)
